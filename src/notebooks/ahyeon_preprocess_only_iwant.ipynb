# %%
import pandas as pd
import re
import os
import string

# %% [markdown]
# # .이 4개 이상인 경우 . 3개로 수정

# %% [markdown]
# ### .이 4개 이상인 경우 확인

# %%
# 체크할 파일 리스트
file_list = ['train.csv', 'dev.csv', 'test.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # .이 4개 이상 있는 dialogue만 필터링
    mask = df['dialogue'].str.contains(r'\.{4,}', regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train.csv
#
# [Dialogue 1]
# #Person1#: 저기, 안녕하세요. 그 짐 좀 도와드릴까요? 제가 옮겨드릴게요.
# #Person2#: 아, 아니에요. 제가 할 수 있어요. 그냥 저쪽에 다시 놓기만 하면 돼요.
# #Person1#: 아니, 제가 도와드릴게요. 아, 아휴.
# #Person2#: 아, 괜찮아요.
# #Person1#: 아, 허리야!
# #Person2#: 괜찮아요, 괜찮아요. 정말 괜찮으세요?
# #Person1#: 여기 좀 누워야겠어요. 아. 여기 자주 오세요?
# #Person2#: 네, 보통 일주일에 다섯 번 와요.
# #Person1#: 아, 아휴. 참, 제 이름은 Justin이에요.
# #Person2#: 저는 Rachel이에요.
# #Person1#: 아, 그래서 어디서 오셨어요?
# #Person2#: 원래는 캘리포니아에서 왔어요...정말 괜찮으세요?
# #Person1#: (괴로워하며) 네, 전 괜찮아요. 어디서 왔어요?
# #Person2#: 음, 유타에 있는 Spanish Fork라는 작은 마을에서 대부분의 시간을 보냈어요.
# #Person1#: 아, 음, 그냥 여기 누워 있어야겠어요.
# #Person2#: 음, 그래서 Justin 씨는 어디서 오셨어요? 매니저 부를게요.
# #Person1#: 아니, 아니요! 그냥 좀 쉬면 돼요. 아, 그래요. 저는, 저는, 아, Spanish Fork에서 왔어요.
# #Person2#: 잠깐만요, 확실해요? 착각하신 것 같은데.
# #Person1#: 아뇨, 아뇨, 아니에요.... 아, 아니, 저는 솔트레이크시티에서 왔어요. 그나저나 직업이 뭐예요? 혹시 보디빌더?
# #Person2#: 아니요, 저는 선생님이에요.
# #Person1#: 아, 뭐 가르치세요?
# #Person2#: 수학이랑 과학을 가르쳐요. 과학 선생님이 아니라도 지금은 의사가 필요하신 것 같아요.
# #Person1#: 아니, 괜찮아요, 괜찮아요. 잠시 후에 일어날게요. 아, 혹시 전화번호 좀 줄 수 있나요? 그냥 혹시나 해서요.
# #Person2#: 아닌 것 같네요. 지금 911이 필요하신 것 같아요.
# #Person1#: (아파서 울며) 오~~~!
# --------------------------------------------------
# [Dialogue 2]
# #Person1#: 안녕하세요. 무엇을 도와드릴까요?
# #Person2#: 네, 이제 체크아웃하려고요. 저는 Adams이고, 방 번호는 312입니다. 여기 열쇠요.
# #Person1#: 잠시만 기다려 주세요, 손님.... 여기가 요금 명세서입니다. 금액이 맞는지 확인해보시겠어요?
# #Person2#: 14파운드는 뭐죠?
# #Person1#: 고객님 방에서 하신 전화 요금입니다.
# #Person2#: 여행자 수표로 결제해도 되나요?
# #Person1#: 물론입니다. 여권 좀 보여주시겠어요?
# #Person2#: 여기 있습니다.
# #Person1#: 각 수표에 서명해 주시겠어요?
# #Person2#: 네, 알겠어요.
# #Person1#: 여기 영수증과 거스름돈입니다, 손님. 감사합니다.
# #Person2#: 감사합니다. 안녕히 계세요.
# --------------------------------------------------
# [Dialogue 3]
# #Person1#: 기분이 안 좋아 보여. 무슨 일이야?
# #Person2#: 아, 별일 없어. 그냥 생각이 많았어.
# #Person1#: 일 때문이야?
# #Person2#: 모든 게 그런 것 같아, 매일 아침 같은 기차 타고, 하루 종일 같은 사무실에 앉아 있고, 같은 TV 프로그램 보고....
# #Person1#: 너 휴가가 필요해.
# #Person2#: 원래 이렇게 항상 같진 않았잖아.
# #Person1#: 무슨 말이야?
# #Person2#: 우리 증조부들은 더 재미있지 않았어? 직접 사냥하고 채소도 재배하고 필요한 걸 스스로 했잖아. 그런데 우린 같은 일만 계속 하잖아. 우리 삶엔 다양성이 없어.
# #Person1#: 너 휴가가 필요해. 그게 지금 네 문제야.
# --------------------------------------------------
# [Dialogue 4]
# #Person1#: 안녕하세요, 여긴 TGC입니다.
# #Person2#: 안녕하세요. 저는 Walter Barry라고 합니다. 런던에서 전화 드립니다. Mr. Grand 좀 바꿔주실 수 있을까요?
# #Person1#: 누구시죠?
# #Person2#: Walter Barry입니다, 런던에서요.
# #Person1#: 무슨 일로 전화하셨나요?
# #Person2#: 그게요, 귀사의 화학 처리 공장이 있는 것으로 알고 있습니다. 저희 회사 LCP, Liquid Control Products는 화학 처리 분야에서 누수 안전성의 선두주자입니다. Mr. Grand와 만나서 TGC가 그런 문제들로부터 보호받고 동시에 비용을 절감할 수 있는 방법을 논의하고 싶습니다.
# #Person1#: 아, 알겠습니다. 그런데 Mr. Grand은 지금 자리에 안 계세요.
# #Person2#: 그분을 언제 뵐 수 있을까요?
# #Person1#: 다음 며칠 동안 매우 바쁘시고, 그 다음에는 뉴욕에 가셔서 언제 시간을 드릴지 말씀드리기 어렵네요.
# #Person2#: 혹시 다른 분과 통화할 수 있을까요?
# #Person1#: 구체적으로 누구랑요?
# #Person2#: 예를 들면, 그의 동료와요?
# #Person1#: 저는 그의 개인 비서입니다. Mr. Grand의 전화를 제가 처리할 수 있습니다.
# #Person2#: 네, 그러면 내일 전화를 드릴까요?
# #Person1#: 아니요, 죄송하지만 내일은 시간이 없으세요. 이렇게 하시죠. 귀사의 상품과 서비스에 대한 세부 정보를 다른 기업에서의 참고자료와 함께 보내주시면, 저희가 연락드리겠습니다.
# #Person2#: 네, 감사합니다. 주소는 알고 있습니다.
# #Person1#: 좋습니다, Mr....
# #Person2#: Barry입니다. 런던에 있는 LCP의 Walter Barry입니다.
# #Person1#: 알겠습니다, Mr. Barry. 귀사의 소식을 기다리겠습니다.
# #Person2#: 감사합니다. 안녕히 계세요.
# #Person1#: 안녕히 가세요.
# --------------------------------------------------
# [Dialogue 5]
# #Person1#: 네, 운전 면허증 좀 보여주시겠어요?
# #Person2#: 뭐라고요? 제가 뭘 잘못했나요?
# #Person1#: 면허증과 차량 등록증을 주세요.
# #Person2#: 아, 네. 글로브 박스 안에 어딘가 있을 거예요. 아, 여기 있네요.
# #Person1#: 선생님, 학교 구역에서 과속하신 거 아셨나요?
# #Person2#: 뭐라고요? 아니요, 몰랐어요. 그건 아마 제 계기판이 고장나서 그런 것 같아요.
# #Person1#: 네, 20마일 제한 구역에서 50마일로 달리고 계셨습니다. 그리고, 방금 지난 교차로에서 완전히 정차하지도 않으셨어요.
# #Person2#: 완전 정차 안 하면 안 되나요?
# #Person1#: 그리고, 뒤쪽 브레이크 등 한 개가 나갔고요, 안전벨트도 착용 안 하셨고, 운전 면허증도 6개월이나 지났네요.
# #Person2#: 그런데 이름이 .... 스미스 경관이라고요? 혹시 이 동네 스미스 가족과 아십니까? 제 아내 사촌의 남편 (이름이 Fred였던 것 같은데) 여기 경찰서에서 일해요. 아님 소방서였나. 어쨌든, 친하게 지내시면 좋잖아요...
# #Person1#: 지금 경찰 매수 시도하시는 건가요? 이런 위반 사항들 때문에 지금 바로 차를 견인할 수도 있습니다.
# #Person2#: 아뇨, 절대 아니에요.
# #Person1#: 그럼요. 여기 벌금 고지서 있습니다. 벌금을 내러 법정에 나오시거나 우편으로 송부하실 수 있습니다. 좋은 하루 되세요.
# #Person2#: 현금도 받나요?
# --------------------------------------------------
# [Dialogue 6]
# #Person1#: 야, 다음 주에 재미있는 거 해보는 거 어때? 우리 시간이 좀 나잖아. 항상 같은 것만 해서 재미없잖아.
# #Person2#: 음... 그래. 무슨 생각 있어?
# #Person1#: 음, 내가 생각한 건... 도서관 같은 건 어때? 뭐? 도서관은 재미없잖아. 언제든 할 수 있잖아. 있지, 월요일에 호수에 가서 수영하는 건 어때?
# #Person2#: 아, 잘 모르겠어. 월요일엔 덥다던데, 나 햇볕에 타잖아. 내 피부가 얼마나 여린지 알잖아.
# #Person1#: 겁쟁이! 그러면... 좋아. 월요일에 호수에 가자. 화요일에는 산악 자전거 타러 가는 거야. 음, 그날은 흐리다더라, 네 피부는 괜찮을 거야.
# #Person2#: 아, 그거 좋다... 근데 저번처럼 또 넘어져서 팔이라도 부러질 것 같아.
# #Person1#: 저번에도 팔 안 부러졌잖아. 이번에도 안 부러질 거야. 자, 월요일에는 호수에 가고, 화요일에는 산악 자전거를 탈 거야. 음, 수요일에는 낚시하러 가자고 생각했어. 저번에 갔을 때 기억나? 나 엄청 큰 물고기 10마리나 잡았었잖아...
# #Person2#: 그래, 기억나. 내가 잡은 건 낡은 부츠 하나였고, 넌 그걸 절대 잊지 않게 하잖아. 그러니까 만약 뭘 하려면, 좀 즐길 수 있는 걸 하고 싶어.
# #Person1#: 음, 그래 알겠어. 그럼 제안해 봐.
# #Person2#: 음, 알겠어. 집에서 팝콘 튀기고, 스크래블이나 다른 보드게임 하는 건 어때? 응, 그런 거 어때?
# #Person1#: 알다시피, 보드게임 좋아하는데 그건 언제든 할 수 있잖아. 그러니까... 금요일이나 토요일에 다 이야기한 것들 하고 나서, 금요일이나 토요일에 산으로 소풍 가는 거 어때? 네 팔도 안 부러지고, 햇볕에도 안 탈 거야. 정말 괜찮을 거야. 그렇게 하자, 응?
# #Person2#: 음.....
# #Person1#: 제발. 그렇게 하자. 재미있을 거야.
# #Person2#: 좋아. 시도해보자.
# #Person1#: 좋아.
# --------------------------------------------------
#
# 파일: dev.csv
#
#
# 파일: test.csv

# %% [markdown]
# ### .이 4개 이상인 경우 . 3개로 수정

# %%
# 체크할 파일 리스트
file_list = ['train.csv', 'dev.csv', 'test.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # .이 4개 이상인 경우, ...으로 대체 (.이 4개, 5개 있는 경우가 있음)
    for v in ['.....', '....']:
        df['dialogue'] = df['dialogue'].apply(lambda x:x.replace(v, '...'))

    # 새로운 파일로 저장 (예: train_cleaned.csv)
    output_path = os.path.join('data', file_name.replace('.csv', '_cleaned.csv'))
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train.csv
#
# ✅ 저장 완료: data/train_cleaned.csv
#
# 파일: dev.csv
#
# ✅ 저장 완료: data/dev_cleaned.csv
#
# 파일: test.csv
#
# ✅ 저장 완료: data/test_cleaned.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # .이 4개 이상 있는 dialogue만 필터링
    mask = df['dialogue'].str.contains(r'\.{4,}', regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train_cleaned.csv
#
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# # \n이나 \<br> 표현 옳게 바꾸기

# %% [markdown]
# ### \n이나 \<br> 표현이 있는 대화 출력

# %%
# 체크할 파일 리스트
file_list = ['train.csv', 'dev.csv', 'test.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # '\n' 또는 '<br>'이 포함된 dialogue만 필터링
    mask = df['dialogue'].str.contains(r'\\n|<br>', regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train_cleaned.csv
#
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# ### \n으로 올바르게 수정

# %%
def preprocess_dialogue(text):
    # fix1
    # \n이 잘못 표시된 경우를 옳게 변경
    # 1. 정규표현식으로 대사 추출
    pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
    raw_dialogues = re.findall(pattern, text, flags=re.DOTALL)

    # fix1
    # 2. 각 문장에서 맨 마지막 문장부호까지 포함한 문장만 남기기
    cleaned_dialogues = []
    for d in raw_dialogues:
        d = d.strip()
        match = re.search(r'^(#Person\d#:.+[.!?])', d, flags=re.DOTALL)
        if match:
            cleaned_dialogues.append(match.group(1).strip())
        else:
            cleaned_dialogues.append(d) # 예외 처리: 문장부호 없을 경우 전체 사용

    # fix1
    # 문장 사이에 \n 삽입
    answer = '\n'.join(cleaned_dialogues)
    
    return answer

# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    df['dialogue'] = df['dialogue'].apply(preprocess_dialogue)

    output_path = os.path.join('data', file_name)
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # '\n' 또는 '<br>'이 포함된 dialogue만 필터링
    mask = df['dialogue'].str.contains(r'\\n|<br>', regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train_cleaned.csv
#
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# # 모음이나 자음만 있는 경우 수정

# %% [markdown]
# ### 모음이나 자음만 있는 대화 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # 정규표현식 패턴 (단어 기준으로 자음 또는 모음만 있는 경우)
    pattern = r'\b[ㄱ-ㅎㅏ-ㅣ]{1,}\b'

    # 조건 만족하는 행 필터링
    mask = df['dialogue'].str.contains(pattern, regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train_cleaned.csv
#
# [Dialogue 1]
# #Person1#: 남자친구 있어?
# #Person2#: 네, 전에 남자친구 있었어요.
# #Person1#: 왜 남자친구 있었다고 해?
# #Person2#: 지난달에 헤어졌거든요.
# #Person1#: 새로 생긴 사람은 있어?
# #Person2#: 음, 아니. 너는 어때?
# #Person1#: 나 솔로야. 사실 나는 네가 내 온라인 여자친구야.
# #Person2#: 하하, 그럼 나는 네 온라인 남자친구네.
# #Person1#: 너 좋아해. 우리 오프라인에서도 사귀어 볼래?
# #Person2#: 음. . . 알았어, 한번 해보자.
# #Person1#: 와! 믿을 수 없어.
# #Person2#: 이게 뭐야?
# #Person1#: 새처럼 날아갈 것 같아.
# #Person2#: ㅎㅎ
# #Person1#: 너무 기뻐. 축배를 들고 싶어.
# #Person2#: 지금 샴페인은 없는데, 이거 어때?
# #Person1#: 괜찮아, 내가 이걸 보낼게.
# #Person2#: 초콜릿으로 만든 거야?
# #Person1#: 내 마음이야; 네가 좋아하는 걸로 만들었어.
# #Person2#: 오, 달콤한 꿈 꿀 것 같아.
# #Person1#: 졸려?
# #Person2#: 좀 졸려. 자야 하는데 아직 자고 싶지 않아.
# #Person1#: 그래, 사무실에서 자는 건 보기 싫으니까.
# #Person2#: 고마워. 그럼 이제 안녕. 키스!
# #Person1#: 여기서 다시 만나자, 자기야.
# --------------------------------------------------
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# ### "ㅎㅎ"가 있는 경우가 한 번 뿐이므로, 문맥에 맞게 '나도 기쁘다.'로 수정

# %%
df = pd.read_csv('data/train_cleaned.csv')

df['dialogue'] = df['dialogue'].apply(lambda x:x.replace('ㅎㅎ', '나도 행복해.'))

# 새로운 CSV 파일로 저장 (index 없이)
df.to_csv("data/train_cleaned.csv", index=False)

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    # 정규표현식 패턴 (단어 기준으로 자음 또는 모음만 있는 경우)
    pattern = r'\b[ㄱ-ㅎㅏ-ㅣ]{1,}\b'

    # 조건 만족하는 행 필터링
    mask = df['dialogue'].str.contains(pattern, regex=True)
    filtered_dialogues = df.loc[mask, 'dialogue']

    for i, dialogue in enumerate(filtered_dialogues, start=1):
        print(f"[Dialogue {i}]")
        print(dialogue)
        print("-" * 50)
# Out:
# 파일: train_cleaned.csv
#
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# # : 뒤에 공백이 없는 경우

# %% [markdown]
# ### 확인

# %%
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')
    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    cleaned_dialogues = []

    for dialogue in df['dialogue']:
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        modified_dialogue = dialogue  # 기본값은 원본 그대로

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:)(\s*)(.+)', d)
            if not match:
                continue
            prefix, space, content = match.groups()
            if space == '':
                print("space :", space)
                print(d)
# Out:
# 파일: train_cleaned.csv
#
# space :
# #Person2#:...사전에서는 일이 먼저 오지. 그래. 나도 그 얘기 다 들어봤어. 우리 선생님이 폴 존스야?
# space :
# #Person2#:...아빠니까. 아빠는 원래 설교야. 삶에 대한 주제로 한 천 번은 말한 것들이 있어서 항상 수업에서 공유하셔.
# space :
# #Person2#:... 그리고 얼굴에 심한 두드러기가 날 수도 있어요.
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# ### 수정

# %%
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')
    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    cleaned_dialogues = []

    for dialogue in df['dialogue']:
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        modified_dialogue = dialogue  # 기본값은 원본 그대로

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:)(\s*)(.+)', d)
            if not match:
                continue
            prefix, space, content = match.groups()
            space = ' '
            modified_dialogue = modified_dialogue.replace(d, prefix + space + content)

        cleaned_dialogues.append(modified_dialogue)

    df['dialogue'] = cleaned_dialogues

    output_path = os.path.join('data', file_name)
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')
    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    cleaned_dialogues = []

    for dialogue in df['dialogue']:
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        modified_dialogue = dialogue  # 기본값은 원본 그대로

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:)(\s*)(.+)', d)
            if not match:
                continue
            prefix, space, content = match.groups()
            if space == '':
                print("space :", space)
                print(d)
# Out:
# 파일: train_cleaned.csv
#
#
# 파일: dev_cleaned.csv
#
#
# 파일: test_cleaned.csv

# %% [markdown]
# # ...이 있는 경우 다루기

# %% [markdown]
# ### ... 앞의 글자 수에 따른 데이터 수 파악

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    one_char_count = 0
    multi_char_count = 0
    only_dots_count = 0

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()

            # '...' 또는 ' ...' 앞에 있는 단어 추출
            for m in re.finditer(r'(\S*)(\s*)\.{3}', content):
                phrase = m.group(1)
                space = m.group(2)  # 줄임표 앞 공백

                if space:  # 공백이 있으면 → last_word 없음으로 간주
                    last_word = ''
                else:
                    last_word = phrase.strip().split()[-1] if phrase.strip() else ''

                # 분류
                if last_word == '':
                    only_dots_count += 1
                elif len(last_word) == 1:
                    one_char_count += 1
                else:
                    multi_char_count += 1

    print(f"🧾 결과:")
    print(f" - 앞 글자 수 없음 (즉, '...' 단독): {only_dots_count}개")
    print(f" - 앞 글자 수 1개 ('가...'): {one_char_count}개")
    print(f" - 앞 글자 수 2개 이상 ('안녕...'): {multi_char_count}개")
# Out:
# 파일: train_cleaned.csv
# 🧾 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 58개
#  - 앞 글자 수 1개 ('가...'): 589개
#  - 앞 글자 수 2개 이상 ('안녕...'): 1445개
#
# 파일: dev_cleaned.csv
#
# 🧾 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 0개
#  - 앞 글자 수 1개 ('가...'): 27개
#  - 앞 글자 수 2개 이상 ('안녕...'): 60개
#
# 파일: test_cleaned.csv
#
# 🧾 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 21개
#  - 앞 글자 수 1개 ('가...'): 29개
#  - 앞 글자 수 2개 이상 ('안녕...'): 66개

# %% [markdown]
# ## ...의 앞 글자 수가 없을 때

# %% [markdown]
# ### 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    only_dots_count = 0

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()

            # '...' 또는 ' ...' 앞에 있는 단어 추출
            for m in re.finditer(r'(\S*)(\s*)\.{3}', content):
                phrase = m.group(1)
                space = m.group(2)  # 줄임표 앞 공백

                if space:  # 공백이 있으면 → last_word 없음으로 간주
                    last_word = ''
                else:
                    last_word = phrase.strip().split()[-1] if phrase.strip() else ''

                # 분류
                if last_word == '':
                    only_dots_count += 1
                    print(content)

    print(f"🧾 {file_name} 결과:")
    print(f" - 앞 글자 수 없음 (즉, '...' 단독): {only_dots_count}개")
# Out:
# 파일: train_cleaned.csv
#
# ...그리고 우리는 새 비키니 입고 선탠하러 나가야겠지.
# ... 누구랑 있었는지? 나는 네가 누구랑 있었는지 몰랐어.
# 그 친구 좀 보게 해 줘. [아빠가 거실 창밖을 봄] ... 저 사람 콧수염 있었네!
# 나도 그 생각하고 있었어. 그런데 ...
# ... 여기요.
# 저기 ... 할 말이 있는데...
# 흠 ... 생각해볼게요.
# ...그리고 내 새 DVD 플레이어. 여기, 내 스테레오를 보여줄게. 이거면 집안이 흔들릴 정도로 음악 들을 수 있어.
# ...2만 달러?
# ... 여기 있어요.
# ... 좋아요, 그럼 이걸로 끝이에요. 여기 양식 있고, 이건 참고할 이전 명함이에요.
# ...사전에서는 일이 먼저 오지. 그래. 나도 그 얘기 다 들어봤어. 우리 선생님이 폴 존스야?
# ...아빠니까. 아빠는 원래 설교야. 삶에 대한 주제로 한 천 번은 말한 것들이 있어서 항상 수업에서 공유하셔.
# ...네, 다 작성했습니다. 여기 양식과 제 오래된 명함이에요.
# Jim? Jim? ... 부엌에서 뭐하고 있어?
# ... 알겠어요, 그럼. 여기 양식이랑, 제 예전 명함이니까 참고해서 만들어 주세요.
# ...할아버지 군대 식량까지.
# 잠시만요, 확인해볼게요. ...네, Mrs. Dick께서 오늘 밤 9시 뉴욕행 112번 비행기 티켓을 예약하셨네요.
# ...바로 거기요! 견인 구역. 오전 7시부터 오후 6시까지 주차 금지라고 써 있잖아요.
# ... 그리고 너는 비에 젖은 머리로 정말 귀여웠어. 그 골목에 서서 비 맞으며 웃고 있는 너를 사진에 담아야 했지...
# ...4시에 강아지 간식 주면서 이빨 닦아주면 좋겠어요.
# ... 잘 다루면 말이죠.
# ... 네, 여기 돈입니다.
# ... 음, 다른 프로그램이나 보고 싶어.
# ...화장실에 실수로 소변이라도 튀면 큰일 나겠지.
# 그런데 이름이 ... 스미스 경관이라고요? 혹시 이 동네 스미스 가족과 아십니까? 제 아내 사촌의 남편 (이름이 Fred였던 것 같은데) 여기 경찰서에서 일해요. 아님 소방서였나. 어쨌든, 친하게 지내시면 좋잖아요...
# ...슈퍼글루로 고치려 했어? 그래도 아내는 바로 알아챌 거야.
# 야, 나 지금 전화 못 받아. 그냥 메시지 남겨 ...
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# ... 그리고 얼굴에 심한 두드러기가 날 수도 있어요.
# ...그리고 화장실 고치는 건가?
# ... 죄송합니다, 지금 그녀의 라인이 바쁩니다. 메시지를 남겨 드릴까요?
# 우리 모두 그런 거 아니야? ... 아, 그리고 네 사촌은 선물용품을 파는구나?
# ...누구랑 있었는지요? 누구랑 있었는지 몰랐잖아요.
# ... 좋아요, 다 했어요. 여기 양식이랑 제 옛날 카드요.
# ...죄송합니다, 지금 통화 중이신데요. 메시지를 남기시겠어요?
# ... 여기 있습니다.
# ...그리고 우리는 새 비키니 입고 태닝할 때고.
# ... 손님?
# ... 그리고 너 머리 다 젖었는데도 너무 귀여웠어. 그 작은 골목길에 서서 비 맞으며 웃고 있는 너 사진 찍어야 했지...
# ...좋아요, 다 했어요. 여기 양식이랑 제 예전 명함이에요.
# 괜찮아요. 올해 처음 박람회에 오신 건가요, Mr. ...?
# 음, 지금은 잘 시간이다. 그러니까, 시작해보자. 옛날 옛적 깊고 어두운 숲 속에 갈색 곰이 살고 있었어 ...
# 알겠어, 저 초록색으로 한번 입어볼게. ... 지금은 어때?
# 알았어, 빨간색 한번 입어볼게. ... 지금은 어때?
# 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서 ... 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# 그래? ...바텐더! ...큰 사이즈 콜라에 얼음과 레몬 좀 주세요... 감사합니다. 여기 돈이요.
# 그래? ...바텐더! ...큰 사이즈 콜라에 얼음과 레몬 좀 주세요... 감사합니다. 여기 돈이요.
# ... 그리고 몇 가지 맛도 보겠지! 여러 나라의 와인이 있고 전문가가 좋은 와인과 그렇지 않은 와인에 대해 조언도 해줄 거래.
# ...다 작성했습니다. 여기 양식이랑 제 명함입니다.
# 🧾 train_cleaned.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 58개
#
# 파일: dev_cleaned.csv
#
# 🧾 dev_cleaned.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 0개
#
# 파일: test_cleaned.csv
#
# 빨리! 사진 찍어! ... 넘겨줘!
# 아, 아니요, 그냥 ... 음...
# 음, 사실은 ... 네. 저기... 과학박물관에 가고 싶은데 몇 시간째 길을 잃어버렸어요. 이 티켓 기계도 어떻게 해야 할지 모르겠고요.
# ...
# ...
# 알겠어요, 한번 볼까요 ... 총 7달러 50센트입니다.
# 안녕, Andrew! 안녕 ...? Andrew.
# 난 누나잖아. 내가 ... 뭐야? 너보다 세 살 많으니까 말하고 싶으면 솔직할 수 있어. 게다가, 너 항상 나한테 그런 말 하곤 했잖아. 나 어릴 때 너 나한테 뚱뚱하다고 그랬잖아.
# 아, 설명하기 너무 복잡해. 며칠 전에 스팸메일에서 정보 찾았거든 ...
# ... 그리고 등록했거든, 490달러밖에 안 들었어.
# 아, 그건 확인 안 해봤는데 ... 하지만, 하지만, 하지만 ... 그런 것 같아.
# 아, 그건 확인 안 해봤는데 ... 하지만, 하지만, 하지만 ... 그런 것 같아.
# 잘 들어, 너 사기당하는 것 같아, 그거 진짜로 이상해. 나 뚱뚱하지 않으니까 믿어. ... 체중 감량하고 싶으면 제대로 해야 돼.
# 그게 ...
# 음 ...
# 많은 사람들이 늦은 밤에 간식을 먹고 싶어 하는데, 그게 대부분 칼로리가 많은 것들이야. 아이스크림 같은 거, 활동을 안 해서 그걸 살로 저장하거든. 버려야 해 ... 오 마이 갓!
# 저칼 ... 아니야, 저칼로리가 아냐. 여기 봐봐. Andrew! 너 먹는 게 아이스크림밖에 없네.
# 글쎄 ...
# 그게 ...
# ...좋아요, 다 했어요. 여기 서식과 제 옛날 명함입니다.
# ...손님?
# 🧾 test_cleaned.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 21개

# %% [markdown]
# ### 수정

# %%
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')
    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    cleaned_dialogues = []

    for dialogue in df['dialogue']:
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        modified_dialogue = dialogue  # 기본값은 원본 그대로

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()
            new_content = content
            
            # 1. 공백 기준으로 문장을 나눔
            sentences = content.split()  # 공백 기준으로 나누기

            # 2. 줄임표(...)가 포함된 문장 찾기
            ellipsis_index = None
            for idx, sentence in enumerate(sentences):
                if '...' in sentence:
                    ellipsis_index = idx
                    break  # 첫 번째 줄임표를 포함한 문장만 찾기

            # 모든 줄임표 순차 탐색
            for m in re.finditer(r'(\S*)(\s*)\.{3}(\s*)(\S*)', content):
                phrase = m.group(1)
                space = m.group(2)  # 줄임표 앞 공백
                
                backward_raw = m.group(4)
                if phrase.strip() and backward_raw.strip():
                    backward_word = backward_raw.strip().split()[0]
                else:
                    backward_word = ''

                if space:  # 공백이 있으면 → last_word 없음으로 간주
                    last_word = ''
                else:
                    last_word = phrase.strip().split()[-1] if phrase.strip() else ''
                forward_word = phrase.strip().split()[-1] if phrase.strip() else ''
                # 분류
                if last_word == '':
                    if forward_word:
                        if ellipsis_index == len(sentences) - 1:
                            if forward_word[-1] not in ['.', ',', '!', '?', ']']:
                                new_content = content.replace(' ...', '.')
                            else:
                                if forward_word in ['Mr.', 'Ms.', 'Mrs.']:
                                    new_content = content.replace(' ...', '')
                                else:
                                    new_content = content.replace('...', '')
                        elif ellipsis_index != 0:
                            if forward_word[-1] not in ['.', ',', '!', '?', ']']:
                                if backward_word and backward_word[0] in ['.', ',', '!', '?']:
                                    new_content = content.replace(' ...', '')
                                else:
                                    new_content = content.replace(' ...', ',')
                            else:
                                if forward_word in ['Mr.', 'Ms.', 'Mrs.']:
                                    new_content = content.replace(' ...', '')
                                else:
                                    new_content = content.replace('...', '')
                    else:
                        if content in ['...', ' ...', '... ', ' ... ']:
                            continue
                        new_content = content.replace('...', '')
                    new_content = new_content.strip()
                    if not new_content.endswith(('.', ',', '!', '?', ']')):
                        new_content += '.'
                    new_content = re.sub(r'\s{2,}', ' ', new_content)
                    full_new_line = prefix + new_content
                    modified_dialogue = modified_dialogue.replace(d, full_new_line)    

        cleaned_dialogues.append(modified_dialogue)

    df['dialogue'] = cleaned_dialogues

    output_path = os.path.join('data', file_name.replace('_cleaned.csv', '_cleaned2.csv'))
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned2.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned2.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned2.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned2.csv', 'dev_cleaned2.csv', 'test_cleaned2.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    only_dots_count = 0

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()

            # '...' 또는 ' ...' 앞에 있는 단어 추출
            for m in re.finditer(r'(\S*)(\s*)\.{3}', content):
                phrase = m.group(1)
                space = m.group(2)  # 줄임표 앞 공백

                if space:  # 공백이 있으면 → last_word 없음으로 간주
                    last_word = ''
                else:
                    last_word = phrase.strip().split()[-1] if phrase.strip() else ''

                # 분류
                if last_word == '':
                    only_dots_count += 1
                    print(content)

    print(f"🧾 {file_name} 결과:")
    print(f" - 앞 글자 수 없음 (즉, '...' 단독): {only_dots_count}개")
# Out:
# 파일: train_cleaned2.csv
#
# 🧾 train_cleaned2.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 0개
#
# 파일: dev_cleaned2.csv
#
# 🧾 dev_cleaned2.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 0개
#
# 파일: test_cleaned2.csv
#
# ...
# ...
# 🧾 test_cleaned2.csv 결과:
#  - 앞 글자 수 없음 (즉, '...' 단독): 2개

# %% [markdown]
# ### 수정 양상 확인

# %%
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    count = 0
    print(f'\n파일: {file_name}\n')

    df_original = pd.read_csv(os.path.join('data', file_name))
    df_modified = pd.read_csv(os.path.join('data', file_name.replace('_cleaned.csv', '_cleaned2.csv')))

    for idx, row in df_original.iterrows():
        orig_dialogue = row['dialogue']
        mod_dialogue = df_modified.loc[idx, 'dialogue']

        orig_lines = orig_dialogue.split('\n')
        mod_lines = mod_dialogue.split('\n')

        for line_idx, line in enumerate(orig_lines):
            if ' ...' in line:
                print(f"[Index: {idx} | 줄 번호: {line_idx}]")
                print("원본 :\n", line)
                print("수정 :\n", mod_lines[line_idx])
                print('-' * 60)
                count += 1
    print(f'\n{file_name} 수정 개수 : ', count)
# Out:
# 파일: train_cleaned.csv
#
# [Index: 137 | 줄 번호: 3]
# 원본 :
#  #Person2#: ...그리고 우리는 새 비키니 입고 선탠하러 나가야겠지.
# 수정 :
#  #Person2#: 그리고 우리는 새 비키니 입고 선탠하러 나가야겠지.
# ------------------------------------------------------------
# [Index: 286 | 줄 번호: 1]
# 원본 :
#  #Person2#: ... 누구랑 있었는지? 나는 네가 누구랑 있었는지 몰랐어.
# 수정 :
#  #Person2#: 누구랑 있었는지? 나는 네가 누구랑 있었는지 몰랐어.
# ------------------------------------------------------------
# [Index: 427 | 줄 번호: 17]
# 원본 :
#  #Person2#: 그 친구 좀 보게 해 줘. [아빠가 거실 창밖을 봄] ... 저 사람 콧수염 있었네!
# 수정 :
#  #Person2#: 그 친구 좀 보게 해 줘. [아빠가 거실 창밖을 봄] 저 사람 콧수염 있었네!
# ------------------------------------------------------------
# [Index: 521 | 줄 번호: 7]
# 원본 :
#  #Person2#: 나도 그 생각하고 있었어. 그런데 ...
# 수정 :
#  #Person2#: 나도 그 생각하고 있었어. 그런데.
# ------------------------------------------------------------
# [Index: 767 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 여기요.
# 수정 :
#  #Person1#: 여기요.
# ------------------------------------------------------------
# [Index: 1039 | 줄 번호: 2]
# 원본 :
#  #Person1#: 저기 ... 할 말이 있는데...
# 수정 :
#  #Person1#: 저기, 할 말이 있는데...
# ------------------------------------------------------------
# [Index: 2573 | 줄 번호: 17]
# 원본 :
#  #Person2#: 흠 ... 생각해볼게요.
# 수정 :
#  #Person2#: 흠, 생각해볼게요.
# ------------------------------------------------------------
# [Index: 2724 | 줄 번호: 3]
# 원본 :
#  #Person2#: ...그리고 내 새 DVD 플레이어. 여기, 내 스테레오를 보여줄게. 이거면 집안이 흔들릴 정도로 음악 들을 수 있어.
# 수정 :
#  #Person2#: 그리고 내 새 DVD 플레이어. 여기, 내 스테레오를 보여줄게. 이거면 집안이 흔들릴 정도로 음악 들을 수 있어.
# ------------------------------------------------------------
# [Index: 2724 | 줄 번호: 16]
# 원본 :
#  #Person1#: ...2만 달러?
# 수정 :
#  #Person1#: 2만 달러?
# ------------------------------------------------------------
# [Index: 2819 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 여기 있어요.
# 수정 :
#  #Person1#: 여기 있어요.
# ------------------------------------------------------------
# [Index: 3454 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 좋아요, 그럼 이걸로 끝이에요. 여기 양식 있고, 이건 참고할 이전 명함이에요.
# 수정 :
#  #Person1#: 좋아요, 그럼 이걸로 끝이에요. 여기 양식 있고, 이건 참고할 이전 명함이에요.
# ------------------------------------------------------------
# [Index: 3543 | 줄 번호: 15]
# 원본 :
#  #Person2#: ...사전에서는 일이 먼저 오지. 그래. 나도 그 얘기 다 들어봤어. 우리 선생님이 폴 존스야?
# 수정 :
#  #Person2#: 사전에서는 일이 먼저 오지. 그래. 나도 그 얘기 다 들어봤어. 우리 선생님이 폴 존스야?
# ------------------------------------------------------------
# [Index: 3543 | 줄 번호: 19]
# 원본 :
#  #Person2#: ...아빠니까. 아빠는 원래 설교야. 삶에 대한 주제로 한 천 번은 말한 것들이 있어서 항상 수업에서 공유하셔.
# 수정 :
#  #Person2#: 아빠니까. 아빠는 원래 설교야. 삶에 대한 주제로 한 천 번은 말한 것들이 있어서 항상 수업에서 공유하셔.
# ------------------------------------------------------------
# [Index: 3590 | 줄 번호: 6]
# 원본 :
#  #Person1#: ...네, 다 작성했습니다. 여기 양식과 제 오래된 명함이에요.
# 수정 :
#  #Person1#: 네, 다 작성했습니다. 여기 양식과 제 오래된 명함이에요.
# ------------------------------------------------------------
# [Index: 3939 | 줄 번호: 0]
# 원본 :
#  #Person1#: Jim? Jim? ... 부엌에서 뭐하고 있어?
# 수정 :
#  #Person1#: Jim? Jim? 부엌에서 뭐하고 있어?
# ------------------------------------------------------------
# [Index: 3943 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 알겠어요, 그럼. 여기 양식이랑, 제 예전 명함이니까 참고해서 만들어 주세요.
# 수정 :
#  #Person1#: 알겠어요, 그럼. 여기 양식이랑, 제 예전 명함이니까 참고해서 만들어 주세요.
# ------------------------------------------------------------
# [Index: 4346 | 줄 번호: 11]
# 원본 :
#  #Person2#: ...할아버지 군대 식량까지.
# 수정 :
#  #Person2#: 할아버지 군대 식량까지.
# ------------------------------------------------------------
# [Index: 4971 | 줄 번호: 2]
# 원본 :
#  #Person1#: 잠시만요, 확인해볼게요. ...네, Mrs. Dick께서 오늘 밤 9시 뉴욕행 112번 비행기 티켓을 예약하셨네요.
# 수정 :
#  #Person1#: 잠시만요, 확인해볼게요. 네, Mrs. Dick께서 오늘 밤 9시 뉴욕행 112번 비행기 티켓을 예약하셨네요.
# ------------------------------------------------------------
# [Index: 5077 | 줄 번호: 7]
# 원본 :
#  #Person2#: ...바로 거기요! 견인 구역. 오전 7시부터 오후 6시까지 주차 금지라고 써 있잖아요.
# 수정 :
#  #Person2#: 바로 거기요! 견인 구역. 오전 7시부터 오후 6시까지 주차 금지라고 써 있잖아요.
# ------------------------------------------------------------
# [Index: 5221 | 줄 번호: 12]
# 원본 :
#  #Person1#: ... 그리고 너는 비에 젖은 머리로 정말 귀여웠어. 그 골목에 서서 비 맞으며 웃고 있는 너를 사진에 담아야 했지...
# 수정 :
#  #Person1#: 그리고 너는 비에 젖은 머리로 정말 귀여웠어. 그 골목에 서서 비 맞으며 웃고 있는 너를 사진에 담아야 했지.
# ------------------------------------------------------------
# [Index: 5259 | 줄 번호: 14]
# 원본 :
#  #Person1#: ...4시에 강아지 간식 주면서 이빨 닦아주면 좋겠어요.
# 수정 :
#  #Person1#: 4시에 강아지 간식 주면서 이빨 닦아주면 좋겠어요.
# ------------------------------------------------------------
# [Index: 5259 | 줄 번호: 38]
# 원본 :
#  #Person1#: ... 잘 다루면 말이죠.
# 수정 :
#  #Person1#: 잘 다루면 말이죠.
# ------------------------------------------------------------
# [Index: 5523 | 줄 번호: 12]
# 원본 :
#  #Person1#: ... 네, 여기 돈입니다.
# 수정 :
#  #Person1#: 네, 여기 돈입니다.
# ------------------------------------------------------------
# [Index: 5647 | 줄 번호: 7]
# 원본 :
#  #Person2#: ... 음, 다른 프로그램이나 보고 싶어.
# 수정 :
#  #Person2#: 음, 다른 프로그램이나 보고 싶어.
# ------------------------------------------------------------
# [Index: 5774 | 줄 번호: 5]
# 원본 :
#  #Person2#: ...화장실에 실수로 소변이라도 튀면 큰일 나겠지.
# 수정 :
#  #Person2#: 화장실에 실수로 소변이라도 튀면 큰일 나겠지.
# ------------------------------------------------------------
# [Index: 6119 | 줄 번호: 9]
# 원본 :
#  #Person2#: 그런데 이름이 ... 스미스 경관이라고요? 혹시 이 동네 스미스 가족과 아십니까? 제 아내 사촌의 남편 (이름이 Fred였던 것 같은데) 여기 경찰서에서 일해요. 아님 소방서였나. 어쨌든, 친하게 지내시면 좋잖아요...
# 수정 :
#  #Person2#: 그런데 이름이, 스미스 경관이라고요? 혹시 이 동네 스미스 가족과 아십니까? 제 아내 사촌의 남편 (이름이 Fred였던 것 같은데) 여기 경찰서에서 일해요. 아님 소방서였나. 어쨌든, 친하게 지내시면 좋잖아요...
# ------------------------------------------------------------
# [Index: 6266 | 줄 번호: 7]
# 원본 :
#  #Person2#: ...슈퍼글루로 고치려 했어? 그래도 아내는 바로 알아챌 거야.
# 수정 :
#  #Person2#: 슈퍼글루로 고치려 했어? 그래도 아내는 바로 알아챌 거야.
# ------------------------------------------------------------
# [Index: 6651 | 줄 번호: 0]
# 원본 :
#  #Person1#: 야, 나 지금 전화 못 받아. 그냥 메시지 남겨 ...
# 수정 :
#  #Person1#: 야, 나 지금 전화 못 받아. 그냥 메시지 남겨.
# ------------------------------------------------------------
# [Index: 6651 | 줄 번호: 1]
# 원본 :
#  #Person2#: Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# 수정 :
#  #Person2#: Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아, 어서 받아, 아, 안돼 그 녀석 소리 들려, 그리고 네 전화 꺼질 것 같아, 아 진짜, 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지, 아 정말, 나 그냥 집에서 빨래할걸, 네 황당한 아이디어 듣고 나간 게 잘못이었어, Greg, Greg? 어디 있는 거야?
# ------------------------------------------------------------
# [Index: 6703 | 줄 번호: 5]
# 원본 :
#  #Person2#: ... 그리고 얼굴에 심한 두드러기가 날 수도 있어요.
# 수정 :
#  #Person2#: 그리고 얼굴에 심한 두드러기가 날 수도 있어요.
# ------------------------------------------------------------
# [Index: 6799 | 줄 번호: 11]
# 원본 :
#  #Person1#: ...그리고 화장실 고치는 건가?
# 수정 :
#  #Person1#: 그리고 화장실 고치는 건가?
# ------------------------------------------------------------
# [Index: 6869 | 줄 번호: 8]
# 원본 :
#  #Person1#: ... 죄송합니다, 지금 그녀의 라인이 바쁩니다. 메시지를 남겨 드릴까요?
# 수정 :
#  #Person1#: 죄송합니다, 지금 그녀의 라인이 바쁩니다. 메시지를 남겨 드릴까요?
# ------------------------------------------------------------
# [Index: 6942 | 줄 번호: 5]
# 원본 :
#  #Person2#: 우리 모두 그런 거 아니야? ... 아, 그리고 네 사촌은 선물용품을 파는구나?
# 수정 :
#  #Person2#: 우리 모두 그런 거 아니야? 아, 그리고 네 사촌은 선물용품을 파는구나?
# ------------------------------------------------------------
# [Index: 7018 | 줄 번호: 1]
# 원본 :
#  #Person2#: ...누구랑 있었는지요? 누구랑 있었는지 몰랐잖아요.
# 수정 :
#  #Person2#: 누구랑 있었는지요? 누구랑 있었는지 몰랐잖아요.
# ------------------------------------------------------------
# [Index: 8562 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 좋아요, 다 했어요. 여기 양식이랑 제 옛날 카드요.
# 수정 :
#  #Person1#: 좋아요, 다 했어요. 여기 양식이랑 제 옛날 카드요.
# ------------------------------------------------------------
# [Index: 8762 | 줄 번호: 8]
# 원본 :
#  #Person1#: ...죄송합니다, 지금 통화 중이신데요. 메시지를 남기시겠어요?
# 수정 :
#  #Person1#: 죄송합니다, 지금 통화 중이신데요. 메시지를 남기시겠어요?
# ------------------------------------------------------------
# [Index: 8988 | 줄 번호: 6]
# 원본 :
#  #Person1#: ... 여기 있습니다.
# 수정 :
#  #Person1#: 여기 있습니다.
# ------------------------------------------------------------
# [Index: 9286 | 줄 번호: 3]
# 원본 :
#  #Person2#: ...그리고 우리는 새 비키니 입고 태닝할 때고.
# 수정 :
#  #Person2#: 그리고 우리는 새 비키니 입고 태닝할 때고.
# ------------------------------------------------------------
# [Index: 9651 | 줄 번호: 13]
# 원본 :
#  #Person3#: ... 손님?
# 수정 :
#  #Person3#: 손님?
# ------------------------------------------------------------
# [Index: 9721 | 줄 번호: 12]
# 원본 :
#  #Person1#: ... 그리고 너 머리 다 젖었는데도 너무 귀여웠어. 그 작은 골목길에 서서 비 맞으며 웃고 있는 너 사진 찍어야 했지...
# 수정 :
#  #Person1#: 그리고 너 머리 다 젖었는데도 너무 귀여웠어. 그 작은 골목길에 서서 비 맞으며 웃고 있는 너 사진 찍어야 했지.
# ------------------------------------------------------------
# [Index: 9900 | 줄 번호: 6]
# 원본 :
#  #Person1#: ...좋아요, 다 했어요. 여기 양식이랑 제 예전 명함이에요.
# 수정 :
#  #Person1#: 좋아요, 다 했어요. 여기 양식이랑 제 예전 명함이에요.
# ------------------------------------------------------------
# [Index: 10136 | 줄 번호: 6]
# 원본 :
#  #Person1#: 괜찮아요. 올해 처음 박람회에 오신 건가요, Mr. ...?
# 수정 :
#  #Person1#: 괜찮아요. 올해 처음 박람회에 오신 건가요, Mr.?
# ------------------------------------------------------------
# [Index: 10176 | 줄 번호: 9]
# 원본 :
#  #Person2#: 음, 지금은 잘 시간이다. 그러니까, 시작해보자. 옛날 옛적 깊고 어두운 숲 속에 갈색 곰이 살고 있었어 ...
# 수정 :
#  #Person2#: 음, 지금은 잘 시간이다. 그러니까, 시작해보자. 옛날 옛적 깊고 어두운 숲 속에 갈색 곰이 살고 있었어.
# ------------------------------------------------------------
# [Index: 11294 | 줄 번호: 4]
# 원본 :
#  #Person1#: 알겠어, 저 초록색으로 한번 입어볼게. ... 지금은 어때?
# 수정 :
#  #Person1#: 알겠어, 저 초록색으로 한번 입어볼게. 지금은 어때?
# ------------------------------------------------------------
# [Index: 11294 | 줄 번호: 8]
# 원본 :
#  #Person1#: 알았어, 빨간색 한번 입어볼게. ... 지금은 어때?
# 수정 :
#  #Person1#: 알았어, 빨간색 한번 입어볼게. 지금은 어때?
# ------------------------------------------------------------
# [Index: 11575 | 줄 번호: 12]
# 원본 :
#  #Person1#: 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서 ... 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# 수정 :
#  #Person1#: 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서, 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# ------------------------------------------------------------
# [Index: 12256 | 줄 번호: 10]
# 원본 :
#  #Person1#: 그래? ...바텐더! ...큰 사이즈 콜라에 얼음과 레몬 좀 주세요... 감사합니다. 여기 돈이요.
# 수정 :
#  #Person1#: 그래? 바텐더! 큰 사이즈 콜라에 얼음과 레몬 좀 주세요 감사합니다. 여기 돈이요.
# ------------------------------------------------------------
# [Index: 12256 | 줄 번호: 13]
# 원본 :
#  #Person2#: ... 그리고 몇 가지 맛도 보겠지! 여러 나라의 와인이 있고 전문가가 좋은 와인과 그렇지 않은 와인에 대해 조언도 해줄 거래.
# 수정 :
#  #Person2#: 그리고 몇 가지 맛도 보겠지! 여러 나라의 와인이 있고 전문가가 좋은 와인과 그렇지 않은 와인에 대해 조언도 해줄 거래.
# ------------------------------------------------------------
# [Index: 12284 | 줄 번호: 6]
# 원본 :
#  #Person1#: ...다 작성했습니다. 여기 양식이랑 제 명함입니다.
# 수정 :
#  #Person1#: 다 작성했습니다. 여기 양식이랑 제 명함입니다.
# ------------------------------------------------------------
#
# train_cleaned.csv 수정 개수 :  49
#
# 파일: dev_cleaned.csv
#
#
# dev_cleaned.csv 수정 개수 :  0
#
# 파일: test_cleaned.csv
#
# [Index: 16 | 줄 번호: 5]
# 원본 :
#  #Person2#: 빨리! 사진 찍어! ... 넘겨줘!
# 수정 :
#  #Person2#: 빨리! 사진 찍어! 넘겨줘!
# ------------------------------------------------------------
# [Index: 130 | 줄 번호: 2]
# 원본 :
#  #Person1#: 아, 아니요, 그냥 ... 음...
# 수정 :
#  #Person1#: 아, 아니요, 그냥, 음...
# ------------------------------------------------------------
# [Index: 130 | 줄 번호: 4]
# 원본 :
#  #Person1#: 음, 사실은 ... 네. 저기... 과학박물관에 가고 싶은데 몇 시간째 길을 잃어버렸어요. 이 티켓 기계도 어떻게 해야 할지 모르겠고요.
# 수정 :
#  #Person1#: 음, 사실은, 네. 저기... 과학박물관에 가고 싶은데 몇 시간째 길을 잃어버렸어요. 이 티켓 기계도 어떻게 해야 할지 모르겠고요.
# ------------------------------------------------------------
# [Index: 154 | 줄 번호: 1]
# 원본 :
#  #Person2#: ...
# 수정 :
#  #Person2#: ...
# ------------------------------------------------------------
# [Index: 154 | 줄 번호: 3]
# 원본 :
#  #Person2#: ...
# 수정 :
#  #Person2#: ...
# ------------------------------------------------------------
# [Index: 184 | 줄 번호: 20]
# 원본 :
#  #Person1#: 알겠어요, 한번 볼까요 ... 총 7달러 50센트입니다.
# 수정 :
#  #Person1#: 알겠어요, 한번 볼까요, 총 7달러 50센트입니다.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 0]
# 원본 :
#  #Person1#: 안녕, Andrew! 안녕 ...? Andrew.
# 수정 :
#  #Person1#: 안녕, Andrew! 안녕? Andrew.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 10]
# 원본 :
#  #Person1#: 난 누나잖아. 내가 ... 뭐야? 너보다 세 살 많으니까 말하고 싶으면 솔직할 수 있어. 게다가, 너 항상 나한테 그런 말 하곤 했잖아. 나 어릴 때 너 나한테 뚱뚱하다고 그랬잖아.
# 수정 :
#  #Person1#: 난 누나잖아. 내가, 뭐야? 너보다 세 살 많으니까 말하고 싶으면 솔직할 수 있어. 게다가, 너 항상 나한테 그런 말 하곤 했잖아. 나 어릴 때 너 나한테 뚱뚱하다고 그랬잖아.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 15]
# 원본 :
#  #Person2#: 아, 설명하기 너무 복잡해. 며칠 전에 스팸메일에서 정보 찾았거든 ...
# 수정 :
#  #Person2#: 아, 설명하기 너무 복잡해. 며칠 전에 스팸메일에서 정보 찾았거든.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 17]
# 원본 :
#  #Person2#: ... 그리고 등록했거든, 490달러밖에 안 들었어.
# 수정 :
#  #Person2#: 그리고 등록했거든, 490달러밖에 안 들었어.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 21]
# 원본 :
#  #Person2#: 아, 그건 확인 안 해봤는데 ... 하지만, 하지만, 하지만 ... 그런 것 같아.
# 수정 :
#  #Person2#: 아, 그건 확인 안 해봤는데, 하지만, 하지만, 하지만, 그런 것 같아.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 22]
# 원본 :
#  #Person1#: 잘 들어, 너 사기당하는 것 같아, 그거 진짜로 이상해. 나 뚱뚱하지 않으니까 믿어. ... 체중 감량하고 싶으면 제대로 해야 돼.
# 수정 :
#  #Person1#: 잘 들어, 너 사기당하는 것 같아, 그거 진짜로 이상해. 나 뚱뚱하지 않으니까 믿어. 체중 감량하고 싶으면 제대로 해야 돼.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 27]
# 원본 :
#  #Person2#: 그게 ...
# 수정 :
#  #Person2#: 그게.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 37]
# 원본 :
#  #Person2#: 음 ...
# 수정 :
#  #Person2#: 음.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 40]
# 원본 :
#  #Person1#: 많은 사람들이 늦은 밤에 간식을 먹고 싶어 하는데, 그게 대부분 칼로리가 많은 것들이야. 아이스크림 같은 거, 활동을 안 해서 그걸 살로 저장하거든. 버려야 해 ... 오 마이 갓!
# 수정 :
#  #Person1#: 많은 사람들이 늦은 밤에 간식을 먹고 싶어 하는데, 그게 대부분 칼로리가 많은 것들이야. 아이스크림 같은 거, 활동을 안 해서 그걸 살로 저장하거든. 버려야 해, 오 마이 갓!
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 44]
# 원본 :
#  #Person1#: 저칼 ... 아니야, 저칼로리가 아냐. 여기 봐봐. Andrew! 너 먹는 게 아이스크림밖에 없네.
# 수정 :
#  #Person1#: 저칼, 아니야, 저칼로리가 아냐. 여기 봐봐. Andrew! 너 먹는 게 아이스크림밖에 없네.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 47]
# 원본 :
#  #Person2#: 글쎄 ...
# 수정 :
#  #Person2#: 글쎄.
# ------------------------------------------------------------
# [Index: 434 | 줄 번호: 49]
# 원본 :
#  #Person2#: 그게 ...
# 수정 :
#  #Person2#: 그게.
# ------------------------------------------------------------
# [Index: 441 | 줄 번호: 6]
# 원본 :
#  #Person1#: ...좋아요, 다 했어요. 여기 서식과 제 옛날 명함입니다.
# 수정 :
#  #Person1#: 좋아요, 다 했어요. 여기 서식과 제 옛날 명함입니다.
# ------------------------------------------------------------
# [Index: 473 | 줄 번호: 18]
# 원본 :
#  #Person1#: ...손님?
# 수정 :
#  #Person1#: 손님?
# ------------------------------------------------------------
#
# test_cleaned.csv 수정 개수 :  20

# %% [markdown]
# ## ...의 앞 글자 수가 1개일 때

# %% [markdown]
# ### 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned2.csv', 'dev_cleaned2.csv', 'test_cleaned2.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    one_char_count = 0
    multi_char_count = 0
    only_dots_count = 0

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()

            # '...' 또는 ' ...' 앞에 있는 단어 추출
            for m in re.finditer(r'(\S*)(\s*)\.{3}', content):
                phrase = m.group(1)
                space = m.group(2)  # 줄임표 앞 공백

                if space:  # 공백이 있으면 → last_word 없음으로 간주
                    last_word = ''
                else:
                    last_word = phrase.strip().split()[-1] if phrase.strip() else ''

                # 분류
                if len(last_word) == 1:
                    one_char_count += 1
                    print(content)

    print(f"🧾 {file_name} 결과:")
    print(f" - 앞 글자 수 1개 ('가...'): {one_char_count}개")
# Out:
# 파일: train_cleaned2.csv
#
# 음... 여섯 개쯤?
# 음... 맛있네요!
# 네...
# 음... 차는 아직 좀 무리이지 않을까? 너 아직 9살이잖아. 인형은 어때?
# 음... 생각보다 작네요. 임대료가 얼마라고 하셨죠?
# 음... 영어랑, 아마도 많이 사용하겠지?
# 아... 벌써 땀이 나요. 너무 뜨거워요. 물이 끓는 것 같아요! 이제 나가도 돼요?
# 음... 7시일 거야.
# 알겠어요. 그럼 다음은 누구였죠? 아... 네, David. 어떻게 생각해요?
# 음... 그는 아주 똑똑해 보였어요. 옷도 깔끔하게 입고 전체적으로 외모도 아주 좋았어요.
# 음... 잘 모르겠어.
# 응... 토네이도는 위험할 수 있어, 그건 사실이야. 시끄러운 기차 소리 같은 것이 들리면 지하실로 가야 해.
# 음... 지금 제 일정이 좀 바쁜데, 주 90분 정도 할 수 있을 것 같아요.
# 음... 제 이름은 밥이고, 여자의 이름은 모르겠어요. 그녀는 말할 수 없는 상태입니다.
# 음... 네, 그런데 그 코트는 더 빨리 필요해요.
# 음... 그럼 당신들은 뭘 하는 거죠?
# 음...
# 음...
# 음... 어떻게 말씀드릴까요? 이 속도라면 석 달 안에 챕터 11을 신청할 겁니다.
# 음...아직 결정 못 했어. 근데 결국엔 내가 하고 싶은 대로 할 거야.
# 경영진은 아마 노동조합을 그다지 좋게 보진 않을 거야. 이해가 가... 노동조합이 경영진에게 꽤 압박을 줄 수 있거든.
# 음... 친구들이 그렇게 하라 했는데 아직 고민 중이야.
# 음... 회계, 재무, 그런 쪽이었던 것 같아요.
# 음... 그렇게 생각하진 않아요. 하지만 성공하고 싶어요.
# 음... 욕실이 있는 더블룸이요. 호수 전망이 있는 방이면 좋겠어요.
# 음... 강점도 몇 가지 있을 수 있지만, 쉽게 진행되진 않을 것 같아요.
# 음...
# 흠... 아마 내가 색깔을 제대로 안 쓴 걸 몰랐나 봐.
# 응... A+로 통과할 거야!
# 또 다른 건 없지? 아... 아, 음악 숙제는?
# 어... 맞아. 상기시켜 줘서 고마워.
# 와... 그녀는 관리비 많이 드는 아내 같아.
# 음... 지금까지 서비스가 만족스러웠으니까 갱신하고 싶어요.
# 네...
# 아, 정말 좋네. 잠깐만, 내가 확인해 볼게. 아... 아쉽게도 그때는 못 갈 것 같아. 5월 25일부터 6월 2일까지 중국에서 출장이야.
# 잠깐만! 켜지 마...
# 음... 혹시 오전에 가능한 시간이 있나요? 그 시간에는 아이들을 학교에서 데려와야 해서요.
# 음...
# 네...
# 음... 한번 볼게. 응, 애완동물 친화적인 건물이라고 하네.
# 음... 그러니까, 사실 우리 할머니가 편찮으셔서 병원에 계셔. 수술도 받으셔야 해서 가보려고 해.
# 편찮으신다는 게...? 무슨 뜻인지 모르겠어.
# 그래도... 음... 수영을 좋아하지 않으세요?
# 내가 찾아볼게. 음... 파란색, 초록색, 분홍색, 검정색... 그리고 흰색 있다. 여기 있어.
# 아, 맞다! 거의 잊을 뻔했네요! 안약이랑, 음... 콘돔도 주실 수 있나요?
# 음... 프린터에 쓸 종이 좀 사올 수 있어? 종이가 다 떨어졌어.
# 아...
# 어... 응! 내가 드럼 배우고 있다고 너한테 천 번은 말했잖아. 이제 잘 치니까, 록 밴드를 만들고 싶어.
# 음... 바쁘긴 한데... 좋아요, 들어오세요. 무슨 일이신가요?
# 우리가 그 사람을 어떻게 생각했는지 봐봐! 어... 그 사람이 명함을 남겼어.
# 그런데 뭐라고 말해야 할지 모르겠어. 나...
# 너... 결혼 준비 수업 받아본 적 있어?
# 네... 부인, 혹시 담배 피우시나요?
# Steven, 나...
# 음... 차멀미 약, 감기약, 진통제 같은 거 준비해야겠죠.
# 음... 하얀 연기는 라디에이터에서 나온 증기인데요, 엔진이 과열돼서 피스톤이 망가졌고 변속기도 고장 난 것 같아요. 차가 멈췄을 때 저희한테 연락해서 견인했어야 했어요.
# 아... 얼마나 걸릴까요? 한 시간 정도면 되나요?
# 음... 그럼 금요일은 어때요?
# 음... 욕조가 있는 더블룸으로 부탁드려요. 가능하면 호수 전망이 있는 방이면 좋겠어요.
# 음... 사진이 있는 신분증이라... 뉴저지 운전면허증 있는데, 괜찮나요?
# 음... 기름값, 음식, 즐길 거리, 많이 쓰지 않을 거야. 그냥 좀 나가자. 우리도 한 번쯤 집을 벗어나야지. 열심히 일했잖아?
# 음... 영수증 가지고 계세요?
# 음... 그거 조금 얻을 수 있을까요?
# 음... 제 생각에는 500달러로 보험 들면 좋겠어요.
# 내 부츠? 음... 그래, 괜찮아.
# 네. 음... 옆머리도 균일하게 해주시고 위쪽은 조금만 정리해주세요.
# 음... 그건 좀 별로예요.
# 음... 여기서 사셨나요?
# 그럴 필요는 없습니다, 선생님. 한번 봅시다... 음... 이 뒤쪽에 있는 작은 스위치 보이세요?
# 그... 연봉은 어떻게 되나요?
# 음, Vincent가 CEO가 된 지 몇 년 안 됐잖아. 음...
# 음... 사실, 너 메모 못 받았구나. 네 상사가 CEO 자리에 공석이 있어서 그 자리를 채우기로 선정됐어. 그러니까 이제 거의 CEO인 셈이지, 공식 발표랑 뭐 그런 것들만 끝나면.
# 저... 이렇게는 숨을 못 쉬겠어요.
# 음... 아직 확실하진 않은데, 아마도 세인트 올번스에서 할 거야.
# 네... 수취인란에 누나 이름을 적어야 하나요?
# 음... 글쎄, 아마 런던이나 암스테르담에서 환승해야 할 것 같아. 너는 어떻게 갈 거야?
# 음... 그래, 괜찮다면 부탁할게.
# 음... 할 수 있는 게 많아요. 란타우 같은 외곽 섬들에 관심 있나요?
# 음... 그렇게 할게요. 정말 감사합니다!
# 아... 이번에는 달라.
# 음... 멕시코 음식점인 La Fajita가 있는데요. 다른 곳들보다는 저렴하지는 않지만, 서비스는 더 좋아요.
# 200달러? 만약 네 신용카드 번호가 털리면, 200달러보다 훨씬 더 큰 손해를 볼 거야! 내 친구가 한 번...
# 아니요, 다른 거... 맞아요.
# 음... 그건 좀 아닌 거 같아요. 먹고 나면 속 쓰릴 거 같네요.
# 음... 잘 모르겠어. 날씨 좋으면 해변에 가볼까 싶어.
# 음... 아! 좋은 생각났어! 후지산 등산하는 건 어때?
# 아... 아는 얼굴은 아닌데.
# 저는 와인 한 잔 마실래요. 음... 여기 레드 와인, 화이트 와인, 포트 와인도 있네요. 상그리아까지요! 해피 아워 스페셜이래요.
# 뭐... 시작하기 전에 건강 검진이라도 받아야 할 것 같아. 네가 농구를 한 지 적어도 5년은 됐잖아.
# 음... 뉴턴이 사과나무에서 떨어지는 걸 본 것 같은데, 확실하진 않아.
# 음... 일반적으로는 그렇지 않습니다. 어떤 부분이 중요하신가요?
# 번, 번... 아, 여기 있네요. 사진과 많이 달라졌네요. 수염과 콧수염이 없어졌고, 안경도 안 썼네요.
# 어... 근데 스티븐하고 화해한 거야?
# 음... 아니에요. 저 영어 공부하러 왔어요. 사실 그리스에서 왔거든요.
# 음... 어디서부터 시작할까?
# 음... 나는 밖에 다니는 걸 좋아하고, 사람들을 돕고 싶어.
# 어... 아니, 현관에 그냥 놔두고 왔어.
# 어... 그거 피크닉 테이블 옆에 놔뒀어. 이 비 오는 날에 가서 가져오라는 건 아니지?
# 물론이죠, 잠시만요. 음... 밤 11시에 하나 있습니다. 조금 늦네요. 차로 가는 게 어떠세요?
# 음... 우리 일에 대해 더 자세히 말해줘요.
# 음... 잠시만요, 확인해볼게요... 죄송하지만, 목요일은 일정이 꽉 차 있습니다. 다음 주 월요일은 어떠세요?
# 오... 와우! 제가 설명하는 동안요.
# 음... 데이비드도 훌륭한 기자야. 그 사람 정말 유쾌해. 네가 만날 누구라도 잘 다루는 방법에 대해 좋은 조언을 해줄 수 있을 거야.
# 무슨 말이야? 뭐... 도둑 맞았잖아.
# 음... 샘플을 무료로 한번 써볼 수 있을까요?
# 아... 욕실 없는 방이라니... 어쨌든 감사합니다.
# 아...
# 네, 맞아요. 다만 개통 수수료, 응급 서비스 수수료, 월별 서비스 수수료, 그리고 추가 분당 요금 같은 것도 있어요. 음...
# 아, 정말요? 잠시만요... 열 달러 지폐로 결제하셨고 제가 드린 건... 아, 죄송해요, 여기 나머지 5달러 있습니다. 정말 죄송합니다.
# 네... 여보세요? Nick 집에 있나요?
# 너... 알고 있었어. 너 레즈비언이지!
# 음... 누가 우리를 후원해줄까? 다들 너무 바빠 보이던데.
# 음... 흥미롭네요. 이 부분에 대해 더 자세히 이야기할 수 있는 사람이 있을까요?
# 음... 약 2시간 정도. 도서관은 잠들기 좋은 곳이긴 하지.
# 곧 보자! 잘 가! (혼잣말) 음... 드디어 끝났다. 저 여자는 물론이고 그녀의 성가신 딸도 정말 싫어.
# 괜찮아요. 아이가 많아서 좋죠, 재밌을 거예요. 아, 그...
# 그냥 인생이라는 게... 이런... 어... 이 그림 같다는 뜻이야.
# 그냥 인생이라는 게... 이런... 어... 이 그림 같다는 뜻이야.
# 흠... 7%는 조금 높아서 어렵겠네요. 이렇게 하면 어떨까요? 4% 할인을 드리지만, 90일의 결제 기한을 드리겠습니다.
# 계산해드릴게요, 음... 총 14달러 30센트입니다.
# 네... 네, 다리 때문이에요, 의사 선생님. 오른쪽 다리에 이상한 통증이 계속 생겨요.
# 어... 알았어. 네가 이겼어. 어서 계산하고 가자.
# 아뇨, 그게 아니고, 그...
# 아... 그... 어느 기계에서 시작할까요? 이 파란 차인가요, Mrs. Miller?
# 아... 그... 어느 기계에서 시작할까요? 이 파란 차인가요, Mrs. Miller?
# 맞아. 어떻게 알았어? 너도 그분한테 수업 들었어? 그분은 그냥 좀...
# 응. 아, 나... 이제 가봐야겠다.
# 음, 아... 한 400달러쯤 될 거야.
# 네... 다 괜찮네요.
# 음... 여기 오게 돼서 정말 좋아요. 여긴 정말 아늑해 보여요.
# 아주 옛날, 내가 어린애였을 때야. 밤중에 물 마시려고 부엌으로 갔었어. 방에서 나와서 계단 위에 섰을 때...
# 음... 그녀는 어떻게 생겼는데?
# 음... 아직 확실하진 않은데, 아마도 세인트 앨반스에서 할 것 같아.
# 음... 편지지랑 봉투 좀 살 수 있을까요?
# 음... 모두 합해서 4달러 60센트입니다.
# 좋아요. 음... 옆머리 길이만 맞춰주시고 윗머리 조금만 다듬어 주세요.
# 음... 아뇨.
# 음... 미국으로 항공편으로 보내면 얼마나 걸리죠?
# 아... 최종 결정하기 전에 좀 더 생각해볼게요.
# 음... 그러면 한 근에 얼마예요?
# 음... 아직 결혼도 안 했는데요. 이 갈색의 말린 과일은 어때요?
# 음... 맛있다.
# 음... 안 갈래. 요즘 몸이 별로 안 좋아.
# 아... 그래, 갈게.
# 아, 10시 반... 자정, 다 똑같아. 6시에 보자.
# 반 시간 정도 해봤어. 흥미로웠지, 그런데... 음... 잘 못 했어.
# 음... 그냥 제가...
# 아, 죄송합니다. 잠시만요... 흠...
# 흠... 흥미롭네요. 여행은 많이 다녀오셨나요?
# 흠... 왜 그런 곳들을 방문하셨나요?
# 음... 꽃다발이면 충분해.
# 소개하게 되어 정말 기쁩니다. 어...
# 맞아요! 미스... 어... 미스...
# 아... 그게 훨씬 더 말이 되네! 하하. 어쨌든 독일 음식은 별로야!
# 집중해, Jimmy! 할 수 있어! 우리가 연습한 대로만 해...
# 그녀의 이름은... 어... 아니타 리베라에요. 제 이름은 로렌스 클락이고, 저는 이 대학교의 교수예요.
# 그래요? 음... 물은 별로 안 좋아해요. 하지만, 뭐, 아마도요.
# 음... 아니요, 괜찮아요.
# 오... 그것도 나도 신날 것 같아!
# 음... 웹사이트라... 그쪽에 대한 책을 읽은 기억은 없네요.
# 음... 가끔 컴퓨터가 플래시를 하긴 하는데, 그걸 말씀하시는 건가요?
# 거기서 뭐 해... 애들처럼 그냥 돌아다녀?
# 음... 한번 생각해봐야겠네요.
# 음... 알겠어요. 그 가격에 살게요.
# 음... 잘 모르겠네요.
# 어... 물론이지! 내가 드럼 배우고 있다고 여러 번 말했잖아. 지금은 잘 칠 줄 알아서, 이제 록 밴드 만들고 싶어.
# 음...
# 음... 이 롤렉스요? 1,000달러예요.
# 알지. 베이킹 믹스에 우유, 계란, 기름 조금 넣고 저으면 돼...
# 흠... 그럴싸하네.
# 그래도 앤...
# 음... 쉽진 않겠지만, 할인이 매력적이면 고려할 수 있어요. 얼마나 할인이 가능하죠?
# 네...
# 윽... 아야!
# 음... 괜찮았지. 날씨가 내가 기대했던 것만큼 좋지는 않았어. 마지막 이틀 동안 구름이 끼더라고. 예보에서는 일주일 내내 햇빛이 쨍쨍하다고 했는데 말이야!
# 응... 호텔 음식은 맛있었는데 가격이 너무 비쌌어. 다음에는 좀 더 저렴한 호텔에 묵어야겠어.
# 음... 그건 맞아.
# 음... 너 메모 못 받았나 본데, 네 상사가 CEO 자리 공백을 채우게 됐어. 공식 발표 끝나면 정식 CEO가 될 거야.
# 음... 알았어요. 시간 좀 있어요.
# 아... 괜찮아... 네가 산다면야!
# 응... 석사나 박사를 따면 뭘 할지 계속 생각하게 돼. 언어를 사랑하지만 Shakespeare 전문가로서의 고액 연봉 직업은 많지 않을 것 같아.
# 음... 네. 치킨 프라이드 스테이크로 할게요.
# 음... 밥으로 할게요.
# 그러게 말이야. 아픈 것도 싫지만, 아... 진짜 치과 진료비 엄청 비싸네. 청구서가 어마어마할 거야!
# 음... 아니.
# 아, 네... 저쪽이군요.
# 음... 잘 모르겠어. 잔인하진 않아도 역시 무서울 것 같아.
# 음... 런던에서 출발하나요?
# 알겠습니다. 가능한 차가 있는지 확인해 볼게요. 음... 없는 것 같네요. 경제형, 소형, 풀 사이즈 차 몇 대와 멋진 미니밴이 있습니다.
# 허브 캡이 빠진 그 낡은 차 말씀하시는 거죠? 아...
# 아, 네... 웨스트 엔드를 구경하려고 하는데요.
# 음... 그럼 외국어 할 줄 아는 거 있어요?
# 응... 문제 없이 잘 통과할 거야!
# 어? 음... 그래도 대가족이 있는 모습을 보니 좋아요.
# 음... 18,168위안입니다.
# 음... 2시에 회의가 있어서 늦어질 수도 있어요. 4시는 어떠세요?
# 어... 네. 그런데 별로 감명 깊진 않았어요. 좀 거만한 것 같더라고요.
# 어... 고등학교에 다녔을 때가... 한 26년이나 27년쯤일 거예요. 확실히 기억은 안 나지만, 32년에 고등학교를 졸업했어요.
# 음... 그렇군요. 사실 다른 항공사를 이용할까 했는데, 좌석은 잡아 둘 필요 없어요.
# 음... 관자놀이 쪽을 더 짧게 잘라주세요.
# 음...
# 음...
# 음... 여기 이동하는 사람들 중 한 명이 있네. 저 사람 좀 스트레스 받아 보이지 않아?
# 음... 잘 모르겠어. 그들이 서두르는 것 같지 않아? 난 늦는 게 스트레스의 큰 원인인 것 같아.
# 아, 그렇군요. 음...
# 음... 여전히 좀 밝은 것 같아요. 더 어두운 색상은 없나요?
# 나... 안 가는 게 낫겠어. 요즘 몸이 안 좋거든.
# 음...
# 음... 저기, 이 차 몇 년 된 건가요?
# 으... 어, 문이 안 열리네요. 아, 괜찮아요. 고장난 것 같아요.
# 어... 우리는 수요일 방과 후에 영화를 볼 생각이에요.
# 음... 그게... 그냥... 그냥 제가...
# 저... 음... 그냥 몇 달러만 빌려줄 수 있는지 알고 싶어서요.
# 저... 음... 그냥 몇 달러만 빌려줄 수 있는지 알고 싶어서요.
# 운동도 하고, 농구도 하고, 웨이트도 해... 그런 거 한 시간 반 정도 해.
# 음... 저 파란색이요. 43 사이즈로 부탁드려요.
# 음... 생각해볼게.
# 어... 아, 안녕, Jane. 읽다가 잠들었나 봐.
# 음... 알았어.
# 나도 좀 의심스러워. 아... 부드럽게 죽이는군, 그 애는 May야.
# 음... 아, 이거 '취미인'이야. 진짜 고전이지.
# 응... 아! 이메일 주소 넣는 걸 깜빡했어.
# 음... 약 20달러 정도 들었어. 정말 싸게 산 것 같아. 그녀가 이거 가지고 노는 사진 봐!
# 음... 여기서 많이 먼가요?
# 음... 처음 시도해보는 건데요. 큰 실수였나요, 아니면 간단히 수정할 수 있는 건가요?
# 음... 이 책은 그림이랑 설명이 잘 어우러져 있네. 아무튼, 여기서 시간을 다 보낼 순 없으니까 이거 살게.
# 음... 가끔은 미스터리를 좋아하긴 하는데 지금은 그런 기분이 아니네요.
# 음... 이자율 높은 걸로 추천해 주실 수 있나요?
# 아, 안녕하세요. 저기, 그... 제 은행 관련 물건들을 잃어버렸어요.
# 음... 생각 좀 해볼게요. 회사에서 신입 직원에게 무료 숙소를 제공할 수 있는지 궁금해요.
# 음... 혹시 잠깐 들러서 쉴 수 있을까?
# 음... 한 10분 정도요.
# 음... 다크 앤 스토미 나이트로 해주세요.
# 음... 지금 제 일정이 꽤 바쁘긴 한데, 매주 90분 정도는 언어 교환에 쓸 수 있을 것 같아요.
# 아, 이건... 네...
# 저번에 대학교의 학생 서비스에 대해 얘기했죠. 오늘은 상담 서비스에 대해 말씀드리려고 합니다. 대학교 상담 서비스는 북쪽 건물에 위치해 있습니다. 상담사로는 Penny Rawson 씨와 Ann David 씨가 있습니다. 오늘 이 자리에 Rawson 씨를 모셔서 그분들의 역할에 대해 논의하려고 합니다. Rawson 씨...
# 음... 네, 그랬으면 좋겠어요. 축제를 보러 에든버러에 가고 싶은데, 어떻게 가는 게 제일 좋은지 잘 모르겠어요. 차는 있는데 상태가 별로 좋지 않거든요. 차로 가면 얼마나 걸릴까요?
# 흠...
# 음... 잠깐만요. 여기 누군가 Sang이라는 이름으로 예약이 있네요. 근데 J - A - N - G로 되어 있네요. J - I - A - N - G가 아니에요. C Sang 씨로 예약이 되어 있어요.
# 음... 하나의 코스가 얼마나 지속되는지 알고 싶어요.
# 자기야, 나...
# 음... 늦을 텐데, 그럼 좀 위험하지 않을까? 나도 안 바빠.
# 아... 나 진짜 초보야. 그래도 적어도 그 테니스 라켓은 받을 수 있겠지.
# 커피면 괜찮아. 음... 어떻게 지냈어?
# 음... 아니, 괜찮아요.
# 무슨 말이야? 아니라고? 오, 안 돼... 안 돼!
# 음... 아니요... 여기 북극 작업장에서 만든 거예요!
# 저... 아, 소곱창 주세요.
# 음... 확인해보니 그 수업은 이미 꽉 찼네요. 몇 주 후에 다시 확인해 보세요. 그때쯤 빈자리가 생길 겁니다. 대기 목록에 이름을 올릴 수 있는데, 차례가 올 때까지 기다리셔야 해요.
# 음... 그냥 일반 보통예금으로 할게요.
# 걸어볼게요. 음... 전화를 안 받네요.
# 아... 정말 실망이야.
# 음... 점심 이후에는 고위 직원 회의에 참석해야 해서 약 2시간 정도 걸릴 것 같은데, 3시에 오실 수 있나요? 4시에 영업팀을 만나기 전에 한 시간 정도 얘기할 수 있을 거예요.
# 음... 나는 요리하는 걸 그렇게 좋아하지는 않아. 식당에서 주문할 수 있는 한, 직접 배울 필요는 없다고 생각해.
# 괜찮을 거예요. 자, 어... 확실히 좋은 아이디어가 있을 거예요. 자, 생각해봐요.
# 저... 저는... 저는 대신 박물관을 방문할 생각이었어요. [ 뭐라고? ] 스노우 스키는 제 취향이 아니에요.
# 응... 근데 이제부터 쇼핑은 줄여야겠어.
# 음... 물 좀 끓이고, 달걀 두 개 휘저어줘.
# 음... 친구들한테 조언을 좀 구하고 결정해야겠네요. 죄송해요.
# 음... 먼저, 코트 서른 벌을 주문하고 싶어요, 주문 번호는 P25J5예요.
# 그리고 신발이요. 음... 주문 번호 P26T5로 25켤레 부탁해요.
# 음... 6 사이즈.
# 그래서 이번 목요일 밤에 같이 놀러 갈래 했지. 극장에서 괜찮은 영화 해... 내 차는 못 쓰는데, BMW 타던 사람이랑 사고가 나서 말야. 버스 시간표도 벌써 확인했어...
# 음... 멕시코 레스토랑이요. 가격도 괜찮고 음식도 좋아요.
# 아... 그리고 귀마개도! 이거 끼고 나가... 자 됐어.
# 나... 숨 막혀.
# 음... 그건 엄지잖아요, Nick.
# 아... 역시 싼 게 비지떡이네. 거기 얼마나 있었어?
# 음... 정확한 크기를 이해하기가 좀 어렵네.
# 음... 너무 늦네요.
# 음...
# 아, 음... 아니, 괜찮아.
# 음... 이 티켓 기계를 어떻게 사용하죠?
# 음...
# 아...
# 음... 아! 별로인 공상과학 영화 보러 가서 극장 뒤쪽에 앉아 그런 영화 비웃으면서 보는 건 어때?
# Hugh 생각나네요. 대부분의 사람들은 그가 조금... 음... 특이하다고 생각했죠. 그 사람 지금 뭐하는지 아세요?
# 아... 네, 물론이죠. 음... 저희는 총 두 군데 위치에 약 2천 명의 직원을 고용하고 있습니다. 대부분의 직원은 여기 본사 공장에서 일합니다. 여기가 당연히 관리 부서가 있는 곳이죠.
# 아... 네, 물론이죠. 음... 저희는 총 두 군데 위치에 약 2천 명의 직원을 고용하고 있습니다. 대부분의 직원은 여기 본사 공장에서 일합니다. 여기가 당연히 관리 부서가 있는 곳이죠.
# 네, 물론입니다. 음... 이제... 어... 우선 저희는 네 개의 주요 부서가 있습니다. 이름에서 알 수 있듯이, 생산 부서는 생산 작업을 담당합니다. 그리고 아시다시피 영국 Bath와 프랑스 Lille에 두 개의 공장이 있습니다. 음... Philippe Rochard가 Lille에서 다른 총괄 매니저입니다.
# 네, 물론입니다. 음... 이제... 어... 우선 저희는 네 개의 주요 부서가 있습니다. 이름에서 알 수 있듯이, 생산 부서는 생산 작업을 담당합니다. 그리고 아시다시피 영국 Bath와 프랑스 Lille에 두 개의 공장이 있습니다. 음... Philippe Rochard가 Lille에서 다른 총괄 매니저입니다.
# 네, 물론입니다. 음... 이제... 어... 우선 저희는 네 개의 주요 부서가 있습니다. 이름에서 알 수 있듯이, 생산 부서는 생산 작업을 담당합니다. 그리고 아시다시피 영국 Bath와 프랑스 Lille에 두 개의 공장이 있습니다. 음... Philippe Rochard가 Lille에서 다른 총괄 매니저입니다.
# 그러나 일상적인 운영면에서는 거의 독립적으로 일을 진행합니다. 하하. 아, 그리고 가장 중요한 부서를 깜빡했네요, 어떤 사람들은 그렇게 말하죠. 그게 바로 재정입니다. 음... 재무 이사는 Fred Rasmussen입니다. 그는 매우 중요한 인물입니다. 그의 임무는 재정적인 측면이 괜찮은지 확인하는 것입니다. 회계사 같은 사람들은 그에게 직접 보고합니다.
# 음, 제가 가장 잘 아는 저희 부서를 예로 들면, Bill Williamson에게 보고하는 여러 다른 부서들이 있습니다. 음... 그리고 구매 부서가 있죠... 생산에 필요한 재료를 구매합니다.
# 네, 당연히 그들이 최고죠? 음... 몇몇 경영진은 이사들이기도 합니다. 물론 전무 이사는 Ernest Roberts입니다. 그리고...
# 네...
# 진짜? 너 참...
# 정말? 음... 그래.
# 아... 그러니까... 음... 그래.
# 아... 그러니까... 음... 그래.
# 흠, 뭐가 문제야? 내가 만든 게... 맘에 안 들어?
# 그럼 우리 한번 생각해보자. 음... 네가 돈을 벌 수 있는 방법을 좀 생각해보면 좋겠어.
# 음... 용돈이요.
# 음... 사람들을 위해서 일할 수도 있어요.
# 음... 우리 구역의 대부분의 아이들이 사탕을 좋아하니까, 그걸로 시작해볼래요.
# 음... 매일 쓰레기 내다버리기요.
# 음... 시도해보는 게 좋겠어.
# 음... 네! 아, 맞아요! 시동이 걸렸어요! 도와주셔서 감사합니다! 내가 기름 넣으라고 했잖아요!
# 음... 향이 너무 강해서 못 참겠어요. 제가 향에 굉장히 민감하거든요.
# 음... 그럼 우리 이거 사도 될 것 같네.
# 참... 엉망이었던 1분기를 다루었으니, 에드! 좋은 소식 좀 줘봐. 이번 달 매출은 어떻게 되어 가고 있어?
# 음... 그게... 나쁜 소식부터 들을래, 아니면 정말 나쁜 소식부터 들을래?
# 음... 이 속도로 가면, 세 달 안에 챕터 11을 신청해야 할 것 같아요.
# 음... 그게 애완동물인가요? 동물원에나 있을 법한 거 아닌가요?
# 어... 공항에서 수하물 맡길 때 항공사 카운터에 놔두고 온 것 같아요.
# 음... 1920년에 뉴욕으로 가서 교육을 시작했는데, 세 주 만에 갑자기 사망했습니다. 그래도 상당히 장수한 편이죠.
# 음...
# 음...
# 나... 나 차로 돌아가야겠다.
# 알겠습니다. 다시 확인해 볼게요. Charles C. Nelson 씨의 오늘 밤...
# 음... 저기... 몇 개 좀 살 수 있을까요?
# 아... 나는 아내를 태우지 않아. 너무 위험하니까. 아내는 버스로 출근하는데, 가끔 자리를 얻기가 힘들고 사람이 많아서 덥고 힘들어.
# 음...
# 아... 그러니까, 내 프로젝트에 도움 좀 줄 수 있을까 해서. 그냥 책이랑 프로젝트 계획만 가져오면 돼. 금방 끝날 거야... 우리, 음.
# 음... 맞는 말이네. 생각해볼게.
# 아... 정말 안타깝네요.
# 음... 잘 안 입는 스타일이에요.
# 아마도, 스키 시즌이니까. 아...스키 시즌 생각 못 했네. 방이 있을까 모르겠어.
# 음... 625달러입니다.
# 잠깐만, 머리핀이 좀...
# 음... 아쉽게도 월요일은 안 될 것 같아요. 시카고로 출장 가야 하거든요.
# 음... 화요일엔 제가 시간이 없어요. 외지에서 온 중요한 손님과 점심 약속이 있어서요. 수요일은 어때요?
# 음... 목요일은 제가 안 될 것 같아요. 인사위원회 회의에 참석해야 해서요.
# 다음 주 화요일요? 잠시만요! 5월 21일이네요. 아, 이럴 수가. 음... 이모 생일 파티에 가기로 약속했어요.
# 잘 봐... 신호 무시하고 오는 차가 너 차를 칠 수도 있어.
# 그래? 음... 난 빨리 걸으면 얼굴이 빨개져.
# 아... 가야 한다니 아쉽네.
# 음... 지갑을 잃어버렸어요, 그리고...
# 음... 독감인 것 같네요.
# 아... 연 2회 정도 동생을 보러 가요.
# 음... 목걸이가 있긴 해요.
# 음... 그 사람들 안 부르기로 했어. 우리 둘만을 위해 예약했거든. 조용히 우리끼리만 저녁을 보내고 싶어서.
# 아... 왜?
# 음... 사실은, 나는 너를 그냥 친구 이상으로 봐왔어. 더 이상 참을 수가 없네. 나는 너에 대해 누구보다 잘 알고, 너의 장점과 단점도 알아. 심지어 침대에서 네가 어느 쪽을 좋아하는지도 알아! 우리 잘 어울릴 것 같지 않아?
# 나... 나...
# 나... 나...
# 응... 나도 그래.
# 그리고 입구에서 남자나 여자에게 입장료를 내. 그다음에 탈의실에서 옷을 벗어. 그런데 정말 놀랐던 게... 조금 민망하더라. 돈 받은 여자가 남자 탈의실 쪽을 다 볼 수 있는 플랫폼에 앉아 있더라고. 이게 사람들이 목욕하는 동안 그들의 물건을 감시하기 위한 거야.
# 내 지갑에 20파운드랑, 음... 열쇠 몇 개, 그리고 영어 사전이 있었어.
# 나... 부모님이 그리워서 그래. 부모님도 나를 보고 싶어하시고.
# 음... 나도 등록해야 하나?
# 꼭 그러지 않아도 돼...
# 글쎄, 뭐... 근데 지난 몇 년간 힘들었어, 이혼했거든.
# 그러게 말이야! 음... 그가 내가 임신하지 않았다고 했어. 괜히 너한테 민폐였으면 미안해. 일부러 그런 건 아니야...
# 음... 너무 격식을 차린 것 같은데? 이 보라색 상의랑 이 청바지는 어때?
# 음... 잘 모르겠어.
# 음... 그럼 이건?
# 아, 문제를 알겠네. 여보, 그 골프공 놓을 자리에 놨던 거 치웠어? 내가 운전석 아래에 뒀던 거... 그게 방해될 거라고 했잖아.
# 음... 알겠어요. 잠깐 시간은 있어요.
# 음...
# 교회에서 뭘 해야 하고, 모든 게 어떤 의미인지 그들에게 말해줘야 해...
# 음... 요즘 투자자들이 주식에는 별로 관심이 없는 것 같더라고요. 너무 위험하니까요. 오픈엔드 펀드는 어떠세요?
# 와... 이 셔츠 괜찮은데, 좀 커 보인다.
# 흠... 별로네. 여기서도 그 가격에 팔아.
# 음... 사실, 정말 즐거운 시간이었어. 그 사람 정말 대단했어!
# 알겠습니다. 보닛 좀 열어볼게요. 네, 시동 한번 걸어보세요. [엔진 시작...] 네, 이제 끄세요. 흠... [그래...] 책을 좀 봐야겠어요... [이 문제는] 연료 라인 문제나 더러운 카뷰레터, 발전기 문제, 아니면 배터리가 약한 걸로 들리네요.
# 좋습니다. 음... 이번 인터뷰가 매우 만족스러웠다고 말씀드리고 싶습니다. 이번 주에 후보자 명단을 축소하고, 다음 주에 2차 인터뷰 일정에 대해 CEO와의 인터뷰 시간을 알려드리겠습니다.
# 음..., 그러면 전략은 뭐야?
# 후... 잠깐만요, 고장이라고요? 스파이웨어? 트로이? 뭐라고요? 어디, 언제, 어떻게요?
# 음... 모레 가면 어때? 내일이 토요일이잖아. 난 토요일의 북적거리는 쇼핑 싫어.
# 음... 여긴 춥네요.
# 음... 색상과 패턴은 마음에 드네요. 그런데 선택할 수 있게 다른 것도 있나요?
# 내가 너무 갑작스러웠나? 놀랐어? 아니면 너는 원하지 않...
# 음... 아니요... 이건 제가 북극에서 만든 거예요!
# 아... 그래서 우리가 빵이랑 양념 가져온 거구나. 그리고 이건 홀리의 감자 샐러드예요.
# 아... 나는 주로 듣는 걸 좋아해. 네가 신랑이니까 너 먼저 해.
# 음... 네, 4년 전이요.
# 아, 네, 아주 즐겁습니다. 주로 긴 시간 동안 일해서 아주 피곤하지만... 음... 12시간까지 일할 때도 있어요. 그래도 전 세계에서 온 사람들을 만나는 게 정말 흥미진진하죠.
# 음... 못 하겠어.
# 음... 아뇨, 괜찮아요. 오늘은 이걸로 충분해요.
# 추가 검사가 필요하네요. 죄송합니다. 이쪽으로 오세요. [뭐라고요? 제가... 뭐가 있나요?] 진정하세요. 괜찮으시죠? 짐 가방을 열어볼게요. 제가 검사하는 동안 가방을 만지지 마세요. [알겠습니다.] 이제 어디 보자. 음... 우선, 이 병에 든 물 같은 액체는 이 지점을 지나가실 수 없습니다.
# 아... 다른 물은 못 마셔요. 시에라 스프링스만 마셔요.
# 음... 아, 그건 제 포켓 나이프에요.
# 아, 읽으려다가 좀... 딴생각을 했어요.
# 음... 그것도 봤어. 공원에 산책 갈까?
# 그렇구나. 음... 우리 부모님은 내가 배우가 되길 바라셔서 미술 학교 보내시려고 해.
# 음... 아직 결정하지 않았어. 근데 보통 내 뜻대로 하게 되더라.
# 음... 너무 번쩍거리네요. 저는 구두에 팬티스타킹을 신으니까, 닫힌 앞코 구두로 찾아볼게요.
# 음... 잘 안 맞네요. 너무 꽉 끼어요. 길이는 맞지만, 폭이 좁아서 발가락이 눌려요. 깔창 넣을 자리도 없고요. 그냥 다른 가게에서 찾아보는 게 나을 것 같아요.
# 아...
# 음... 네, 좋습니다. 그에게 그 시간에 만나겠다고 전해주세요.
# 음... 네, 맞는 말이에요.
# 음, 보자. 내 리스트가 있어. 음... 너희 형제들은 햄버거, 치즈, 빵 가져온대.
# 음...
# 네... 저기서 복사와 팩스를 보낼 수 있어요.
# 음... 우리 업무에 대한 자세한 정보 좀 더 알려주세요.
# 어... 그렇지! 내가 드럼 배우고 있다고 몇 번이나 말했잖아. 이제 잘 치게 돼서 밴드 한번 만들어 보려고.
# 아... 근데 다이어트하면서 운동도 조금씩 해야 해.
# 음... 잘 모르겠네요. 내일 아침에 들러서 아파트를 볼 수 있을까요?
# 알겠어요, 고마워요. 음... 아파트가 정확히 어디에 위치해 있나요?
# 네... 음... 학교에서 물리를 공부하느라 생물을 포기했는데 사실 생물이 더 좋아요. 더 공부하고 싶어요. 기술적으로 독일어도 중요해서 그것도 하고 싶어요.
# 음... 누군가 얘기했던 것 같기도 해. 재밌어?
# 아... 그런데, 크리스마스 파티 때 사무실에서 따님과 함께 계신 걸 봤어요. 정말 아름다우시더군요!
# 음... 어...
# 음... 어...
# 앉으세요. 음... 당신이 Mr. Smith 맞으신가요?
# 음... 한 사람이 술래고, 그 술래가 나머지를 잡으려고 해. 내가 누굴 잡기 전에 다른 사람이 날 잡으면 돼.
# 음..., 애들이 너무 어려서 조금 무서울 수도 있지만, 남들이 타는 걸 보는 건 좋아할 것 같아.
# 음... 네... 856674 / ros입니다.
# 음... 네... 856674 / ros입니다.
# 흠... 다릴은 빨간 속옷을 입을 사람 같진 않네...
# 뭐... 딱 한 번만 봤는데, 그 후 두 달 동안은 사람들한테 말할 때 터미네이터인 척했어.
# 음... 글쎄요... 이전 직장에서 매일 밤 컴퓨터를 사용하긴 했습니다.
# 음... 어, 웹 페이지, 웹 페이지... 그 책은 읽어본 적이 없고, CGI라는 건 사용해 본 적이 없습니다.
# 음... 외국 커피숍에서 한 번 자바를 마셔본 적은 있지만, 그런 걸 말씀하시는 건 아니겠죠.
# 음...
# 응... 소파 밑, 빨래 더미 속, 책장 뒤...
# 응... 소파 밑, 빨래 더미 속, 책장 뒤...
# 음... 지금 꽤 따뜻해요.
# 음... 너는 뭐에 관심 있어?
# Joanna, 그건 좀...
# 그러니까, 네가 운전을 참... 내 생각엔 아직 좋은 생각 아닌 것 같아.
# 어... 네, 안녕하세요! 수지 있나요?
# 음... 솔직히 정말 좋았어. 정말 놀라웠어!
# 음... 독감에 걸린 것 같군요.
# 음... 약 30분 뒤에 출발합니다.
# 음... 중국에서 섬유 컨테이너 50개를 수입하시는군요. 다음 주 말까지는 주문이 접수될 수 있을 거예요. 닝보라는 항구 도시에 도착하는 데 2일이 걸릴 거고요. 화물은 바다에서 3주 걸릴 예정이며, 오늘로부터 약 한 달 후에는 로스앤젤레스에 도착할 겁니다. 국내 배송은 여러분의 책임이니 로스앤젤레스 항구와 직접 조율하시면 됩니다.
# 청중의 규모와 관심사를 고려하는 게 좋아. 즉, 누가 듣고 있는지, 그들이 무엇을 듣고 싶어 하는지를 생각해야 해... 사람들의 관심을 끌 수 있는 그래픽이나 애니메이션을 담은 PPT를 준비할 수도 있지만, 너무 과하지 않도록 주의해야 해.
# 음... 아직 잘 모르겠어요. 더 둘러봐야 알 것 같아요. 그래도 여기 사람들은 모두 친절해요.
# 음... 안 될 것 같은데. 오늘 밤 너희 엄마 데리러 가야 해.
# 어... 교수님, 잠시만요. 다시 한 번 말씀해 주실 수 있나요?
# 음... 노트에 빈칸을 남겨두고 나중에 나한테 물어봐. 도움이 되니?
# 음..., 어머니의 날, 독립기념일, 추수감사절, 크리스마스, 새해 첫날, 그리고 발렌타인 데이요.
# 음... 아닌 것 같아요. 너무 꽉 끼네요. 길이는 맞지만 발가락이 꼬집히고 깔창 넣을 공간도 없어요. 오늘은 컨디션이 좋지가 않아서 다시 올게요.
# 음... 그래요. 그리고 상태는 어떤가요?
# 응...
# 음... 그래. 무슨 생각 있어?
# 음, 내가 생각한 건... 도서관 같은 건 어때? 뭐? 도서관은 재미없잖아. 언제든 할 수 있잖아. 있지, 월요일에 호수에 가서 수영하는 건 어때?
# 음...
# 집에서 멀지 않네. 음... 잠깐만, 걸어서 20분 정도 걸려. 걸어서 올 수 있겠어?
# 음... 너도 알다시피 나 윌리엄이랑 친구야.
# 나... 시험에 떨어졌어. 좀 더 열심히 공부했으면 좋았을 텐데...
# 음... 두 달 전쯤에 시작했어. 아, 아니, 세 달 전쯤이었을 거야. 처음엔 감기인 줄 알았어. 콧물이 나고 열이 좀 있었거든.
# 네, 맞아요! 작년에 샀죠. 음... 지금도 상태가 아주 좋아요.
# 음... 그럼 한 근에 얼마예요?
# 어... 저는 아직 결혼도 안 했는데요. 이 갈색 건과는 어떤가요?
# 아, 그건 녹용이에요. 그건 당신에게 도움이 돼요. 음... 뭐라고 표현해야 할지...
# 일단, 그녀는 너무 예쁘고, 항상 긍정적이면서도 상냥해. 누가 그녀를 안 좋아하겠어? 아, 모르겠어. 우리가 엄청 잘 어울린다고 생각은 하는데. 만약 내 착각이면 어쩌지. 단지 예의상 나한테 잘해준 건 아닐까 싶기도 하고. 아... 너무 안 좋은 생각이었어.
# 음... 5,500위안까지는 어떻게 해드리겠지만, 이게 최저 가격이에요.
# 음...
# 바이러스요? 음... 알겠어요. 아니에요! 열도 없고, 저 괜찮아요.
# 아, 네... 잠깐만요, 멈췄다고요? 스파이웨어? 트로이 목마! 그게 뭐죠? 어디서 온 거죠? 언제요?
# 나한테 보여줘 봐... 아, 아빠. [뭐?] 레시피 한 페이지를 빠뜨리셨나 봐요!
# 네... 이해해 주셔서 감사합니다. 이제 가봐야겠어요.
# 잠깐만 생각해볼게. 음... 아, 식당 이름이 생각이 날 듯 말 듯 하네! 잠시만 기다려봐, 생각나겠지.
# 음... 생각났어?
# 음, C... 마이너스요.
# 음... 지역 커뮤니티에서 가사 청소나 아이 돌보기를 좀 해볼까 생각 중이셔.
# 🧾 train_cleaned2.csv 결과:
#  - 앞 글자 수 1개 ('가...'): 589개
#
# 파일: dev_cleaned2.csv
#
# 아... 그게 무슨 뜻인지 모르겠어.
# 어디 한번 봅시다. 음... 상태가 별로 좋지 않네요. 아마 사랑니를 뽑아야 할 것 같아요. 어금니를 누르고 있어서 통증이 심한 것 같네요.
# 여기 저희 브로셔입니다. 음... 소형... 네. 이 섹션에서 모델을 선택해 주세요.
# 고마워요. 휴... 출발 대기하면서 오랫동안 기다렸어요.
# 음... 오늘 뭐 입지?
# 음... 내 식기들은 어디 있지?
# 음... 아마도, 생각 좀 해봐야겠어. 크기도 충분히 커야 해.
# 아... 그냥 걸어서 올라가자. 더 재밌을 것 같아.
# 음... 이건 가격은 좀 더 비싸지만 음질이 훨씬 좋아요. 이 부분이 플라스틱 대신 나무로 만들어졌고, 톤 조절 기능도 있어요.
# 음... 그렇다면 다른 게 가성비가 더 좋을 거예요. 이게 훨씬 저렴하거든요. 고객님들이 많이 구매하시고 만족하시더라고요.
# 음... 그럼 저렴한 걸로 할게요. 수표로 결제할 수 있나요?
# 음... 오전 11시 30분에 일어났어. 지금 브런치 먹고 있어.
# 음... 좋은 생각이야. 내일부터 시도해볼게. 정말 고마워. 너랑 얘기하니 좋다.
# 어... 그 개야.
# 안 돼, 안 돼, 스테이크는 새 집에 적응하게 도와줄 거라고. 어, 너 뭐 하는 거야? 아... 왜 스테이크를 밖으로 던진 거야?
# 음... 그럼 다음 이틀은 어때?
# 아... 그렇군요. 그럼 다른 추천 요리 있나요?
# 아, 음... 고마워. #Person1#, 라이터 있어?
# 그러길 바라. 조금만 더 가면 돼... 두 명 남았어... 한 명 남았어... 우리 차례다.
# 아...
# 알잖아, 여자들은 이런 차 좋아해. 봐봐, 선루프도 있어! 상상해봐... 시원하고 별이 빛나는 밤...
# 대각선으로 된 검은색과 빨간색 줄무늬가 정말 보수적이긴 해...
# 음... 너 너무 꾸민 것 같아. 이 보라색 상의랑 청바지는 어때?
# 음... 사실, 어제 정말 환상적인 시간이었어. 그 사람 정말 멋졌어!
# 음, 제가 또 가지고 있는 건...
# 세 시 반이구나. 음... 우리 기다려야겠다. 왜, 뭐 먹고 싶어?
# 음...
# 🧾 dev_cleaned2.csv 결과:
#  - 앞 글자 수 1개 ('가...'): 27개
#
# 파일: test_cleaned2.csv
#
# 아... 알겠어. 이봐, 여기 표지판에 봐, 등산 금지라고 하네.
# 음... 죄송합니다. 잠시만 기다려 주실래요? 관련 부서에 확인해보겠습니다.
# 그래도 재밌잖아. 저 두 명의 못생긴 할머니들 좀 봐... 아니, 할아버지들인가?
# 어... 네... 물론이죠!
# 어... 네... 물론이죠!
# 음... 그럼, 다섯 개의 테이블이 필요할 것 같아요. 전시용으로요. 스탠드는 저희가 따로 가져올게요. 아마도 방에 오버헤드 프로젝터와 음향 시스템이 있을 거죠? 저희가 가기 전에 누군가가 작동 상태를 확인해 줄 수 있을까요?
# 음... 아니요. 하지만 대략적인 추정치를 드릴 수 있을 거고, 그 숫자를 기준으로 예산을 짤게요. 초대장은 100장을 보냈어요...
# 어, 여기가 어디지? 쯧쯧, 음...
# 아, 아니요, 그냥, 음...
# 나... 나... 아니, 그럴 리가 없어...
# 나... 나... 아니, 그럴 리가 없어...
# 음... Vanilla Ice라. 그의 가장 유명한 노래인 'Ice Ice Baby'는 아는데, 다른 노래들은 잘 몰라.
# 음... 재즈 클럽은 갔다 왔어요?
# 음... 네. 오른쪽으로 돌아서 두 번째 나오는 길에서 왼쪽으로 가세요.
# 어...엄마, 약속할게요. 소리 하나도 안 낼게요.
# 음... 핀란드 헬싱키로 갑니다.
# 아, 아, 아...
# 오...
# 음... 그래. 근데 별로 감명받지는 않았어. 좀 거만한 것 같아.
# 먼저 무게를 재봐야겠네요. 음... 오그램이 초과되었네요. 보통 우편이나 등기로 보내실 건가요?
# 등기랑 익일 배송까지 해서... 음... 모두 해서 7달러입니다.
# 음... 복권에 당첨되면 세계 여행 티켓 두 장을 살 거야.
# 음... 네! 여자친구에게 줄 멋진 선물을 찾고 있어요. 다음 주 금요일이 우리 5주년이에요.
# 와... 정말 예쁘네요. Jess가 정말 좋아할 거예요. 하지만... 더 섬세한 것, 예를 들어 목걸이를 생각하고 있었어요.
# 음... 사실은... Jess에게 프로포즈도 생각하고 있었어요... 그냥 너무 긴장돼서요.
# 어... 제가 설거지 좀 했어요. 아니, 다 같이 했어요!
# 네, 어... 밖에 놨어요. 저, 이제 가봐야 할 것 같아요.
# 음... 그래서 뭘 했는데?
# 네, 하지만... 음...
# 🧾 test_cleaned2.csv 결과:
#  - 앞 글자 수 1개 ('가...'): 29개

# %% [markdown]
# ### 수정

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned2.csv', 'dev_cleaned2.csv', 'test_cleaned2.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    cleaned_dialogues = []

    for dialogue in df['dialogue']:
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        cleaned_blocks = []

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                cleaned_blocks.append(d)
                continue

            prefix, content = match.groups()
            stripped_content = content.strip()
            
            # content 전체가 '음...', '흠...', '어...', '와...', '나...' 인 경우는 그대로 둠
            if re.fullmatch(r'(음|흠|어|와|나)\s*\.{3}', stripped_content):
                cleaned_blocks.append(d)
                continue

            # content 중간의 '음...', '흠...', '어...', '와...', '나...'  제거
            new_content = re.sub(r'\b(음|흠|어|와|나)\s*\.{3}', '', content)
            new_content = re.sub(r'\b(나)\s*\.{3}', '', content, count=1)
            new_content = re.sub(r'\s{2,}', ' ', new_content)
            new_content = re.sub(r',\s*$', '.', new_content)
            cleaned_blocks.append(prefix + new_content.strip())

        # cleaned_blocks를 하나로 이어붙여 다시 dialogue로 구성
        cleaned_dialogues.append('\n'.join(cleaned_blocks))

    df['dialogue'] = cleaned_dialogues

    # 새로운 파일로 저장 (예: train_cleaned.csv)
    output_path = os.path.join('data', file_name.replace('_cleaned.csv', '_cleaned2.csv'))
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned2.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned2.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned2.csv

# %% [markdown]
# ## ...의 앞 글자 수가 2개 이상일 때

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned2.csv', 'dev_cleaned2.csv', 'test_cleaned2.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    multi_char_count = 0

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            d = d.strip()
            match = re.search(r'^(#Person\d#:\s*)(.+)', d)
            if not match:
                continue
            prefix, content = match.groups()

            # '...' 또는 ' ...' 앞에 있는 단어 추출
            for m in re.finditer(r'(\S*)\s*\.{3}', content):
                word = m.group(1)
                if len(word) > 1:
                    multi_char_count += 1
                    print(content)

    print(f"🧾 {file_name} 결과:")
    print(f" - 앞 글자 수 2개 이상 ('안녕...'): {multi_char_count}개")
# Out:
# 파일: train_cleaned2.csv
#
# 고맙네요! 그런데 저는 춤 잘 못 춰요...
# 알겠습니다... 혹시 지원 관련해서 궁금한 게 있으세요?
# 아, 괜찮아요. 잠시만 기다리시면 확인해 볼게요. Judy Liao... 잠시만요... 네, 여기 있네요. Judy Liao. 이력서를 받았습니다.
# Veronica... 너무 불공평하잖아! 난 널 사랑해, 우리가 처음 만난 날부터! 다 잘 되어가고 있었는데 그 바보가 나타나서 모든 걸 망쳤어! 너 말대로 의사가 되고 싶다 그래서 난 의대에 갔어! 이제 넌 내 거야... 어떻게든...
# 맞아... 나도 그래.
# 정말요? 스코틀랜드가 고급 초콜릿 생산지로 유명하진 않은 것 같은데요...
# 아버지가 도서관에서 빌려 오셔서 서점에서 사려던 참이었는데... 어쨌든 얼마 내야 하나요?
# 그니까... 돈이 행복을 주진 않지만, 많은 책임을 덜어주잖아.
# 오늘 여기 온 이유는... 음, 두 가지 부탁을 드리고 싶어서요.
# 그리고 두 번째는... 정상적인 건지 잘 모르겠어요.
# 저는... 저는 링컨 간선도로 남쪽 방향 차선에 있습니다. 워싱턴 터널에서 약 15마일 정도 떨어져 있고, 이 여자는 기다릴 수 없어요.
# 음, 황금 아치... 맥도날드가 보여요.
# 이런, 몰랐어. 난 정말 몰랐어...
# 물론이지! 재미있을 거야! 남자들끼리 노는 밤 같은 느낌일 거야... 뭐, 그런 느낌?
# 너랑 아버지께 정말 고마워. 최선을 다할게. 근데 알다시피 내 영어 실력이 좋진 않아서...
# 보자... 바지 두 벌, 여성 드레스 한 벌하고 남성 코트 한 벌이네요.
# 저, 그게... 늦잠 잤어요.
# 그게, 지갑을 잃어버려서요, 그리고...
# 오늘 아침에. 그러니까...
# 승무원이 자꾸 나한테 웃는 것 같아. 왜 그런지 궁금하네...
# 우리 둘의 결혼 소원을 이룰 시간이요...
# '네'라고 해줬으면 좋겠어요...
# 그 마음은 이해해. 하지만...
# 근데 인도 음식 말고도 다른 것도 제공할 것 같은데...
# 알겠어... 사실 완두콩이랑 당근은 상관없는데, 브로콜리랑 콜리플라워는 너무 싫어.
# 그런가... 문제는 좋은 소식만 있다면, 모든 이야기를 온전히 알고 있는 건지, 아니면 그냥 좋은 말로만 포장된 건지 어떻게 알아? 객관적인 저널리즘 같지는 않은데, 이야기의 양쪽 면과 모든 사실을 보도하는 게 아니니까.
# 잠깐, 잠깐... 어디 가니?
# SF 스릴러인데... 제목은 잘 모르겠지만 PG 등급이에요.
# 그 친구 좀 보게 해 줘. [아빠가 거실 창밖을 봄] ... 저 사람 콧수염 있었네!
# 음, 저기... 나쁜 소식 먼저 들을래, 아니면 더 나쁜 소식?
# 이런... 우리는 얼마나 빨리 돈을 잃고 있는 건지?
# 뭐라고? 이런, 어떻게 이런 일이... 그럼 나쁜 소식은 뭐야?
# 감사합니다. 어디 보자... 여기 계산서에 오류가 있는 것 같아요. 확인해 주실 수 있나요?
# 우와! 약이 너무 많네요... 알약 삼키는 거 정말 싫어하는데. 직장에 가도 될까요?
# 뭐, 사실 내가 더 바빴던 것 같은데...
# 네가 4를 굴렸네. 어디 보자... 외국 영화 칸에 멈췄네.
# 잠시만 기다려 주세요... 여기 24,060위안과 영수증이 있습니다. 확인해 보세요.
# 음, 아마 시계랑 카메라를 팔거나... 아니면 어딘가에서 웨이트리스로 일해서 집에 돌아갈 비행기표 살 돈을 모아야겠지.
# 나도 그 생각하고 있었어. 그런데 ...
# 응, 준비해야 할 게 진짜 많아. 웨딩 사진, 웨딩 드레스, 케이터링, 교통편, 호텔 등등...
# 맞아... 하지만 아마 노동자들한테는 더 좋을 거야. 왜냐면 노조의 목적이 약자들을 돌보는 거니까. 약자들이 큰 보스들에 맞서려면 함께 해야 하고, 노동조합은 그런 약자들에게 목소리를 주는 데 주력을 두고 있어.
# 안 믿겨요. 새 라켓이랑 새 공 10개가 들어있었거든요...
# 그렇군요. 보통 화요일 아침엔 여기 계시는데...
# 음, 글쎄요... 파란색은 보이지 않네요. 대신 이 초록색은 어때요?
# 음, 보자... 원래는 34달러에 판매되는데, 세일해서 16달러에요.
# 가고 싶긴 한데, 아침에 피아노 연습하고 오후에는 미술 수업이 있어서...
# 아, 알았어 알았어, 이제... 처음 만나게 되는 사람, 그러니까 Claudia의 부모님 같은 사람들 만날 때는 시간에 맞춰 가는 게 좋아.
# 가야 했는데... 최근에 영화 본 거 있어?
# 잡아, 이준아! 공 쪽으로 달려! 앗! 속도 줄여, 부딪히겠어...
# 네, 가능한 방을 확인해볼게요... 네, 4층에 정말 멋진 전망을 가진 방이 있습니다.
# 아름다운 해변이랑 야자수가 있고...
# 그래, 그런데 지금 당장은 그녀를 잊기 힘들어. 우리가 거의 5년이나 함께했었잖아. 정말 힘들어...
# 하지만 Steven, 왜 휴가를 안 내고... 스티븐, 왜 말이 없어? 아직 거기 있어?
# 아, 저기... 이더넷을 쓸 수가 없어요. 제 컴퓨터는 무선만 돼요.
# 이쪽으로 와 보세요. 최신 가전제품으로 완비되어 있는데요, 다만...
# 너 요즘 정크 푸드를 별로 안 먹고 기름진 음식도 피하는 것 같더라. 이 식단이 건강에 좋다고는 하는데...
# 응, 정말 좋은 책이야! 세 챕터 복사했어. 정말 멋진 차트들이 있고...
# 알겠습니다. 그러면 이게 최종 계산서이고 총 금액은...?
# 그는 아직 집에 안 왔어요... 왜 이렇게 질문이 많아요, Paul?
# 알아, 알아. 근데 있잖아, Tom 공항에서 데려와야 하거든. 내 차 쓸 수 있을까...?
# 별로 많이 보진 않습니다... 대략 한 시간 정도요.
# 아, 그건 별로... 다만 그 프로모션 정보는 받고 싶어요.
# 물론이죠... 여기 명함입니다.
# 음, 또 여러 가지가 있는데...
# 보자... 수요일 아침에 너 보러 갈 수 있어.
# 맞아, 그리고 잘못되면 책임도 져야 해. 그게 내 옛 상사에게 일어난 일이거든...
# 원래는 캘리포니아에서 왔어요...정말 괜찮으세요?
# 아뇨, 아뇨, 아니에요.... 아, 아니, 저는 솔트레이크시티에서 왔어요. 그나저나 직업이 뭐예요? 혹시 보디빌더?
# 음, 어디 보자... 물 좀 끓여줘.
# 음, 연봉이 어떤지 궁금해서. 그러니까... 회사보다는 많이 낮은 편이야?
# 네, 페인트통에 얼음을 가득 넣었습니다 그리고...
# 그럼 페인트통을 제거하셨나요... Mr. Schuller, 아직 통화 중이신가요?
# 아휴, 제발, 그의 예순 번째 생일인데, 좀 더 특별한 걸 줘야 한다고 생각하지 않아? 뭔가 좋은 걸, 뭔가...
# 국립미술관이요. 그리고...
# 물론 아니지. 중요한 건 팀으로서의 경기야. 서로 패스를 주고받고, 수비수를 따돌리는 게 중요해. 프리킥은 모든 팀원들의 노력의 결과니까. 하지만 어떤 프리킥은...
# 알았어, 내가 그럴 줄 알았어...
# 그리고 혀도 좀 보여주시고요... 감사합니다. 그만하면 됐어요. 편도선염이 좀 있고 목이 부어있네요. 식욕은 어떤가요?
# 바쁘긴 한데... 좋아요, 들어오세요. 무슨 일이신가요?
# 정말 그리 간단한 거야? 그렇게 운영하는 게 별로 효율적이지 않은 것 같은데...
# Sandy, 우리 실수한 것 같아...
# 그렇군요...
# 음, 문제는 그녀가 날 눈여겨보지 않는다는 거야. 아니면...
# 모르겠어. 지역 사회 돕는 건 좋지만, 시간이 있을지 모르겠네...
# 그럼 뭐 시켜도 다 괜찮다는 거네? 그럼...
# 네, 정말 흥미롭네요. 활동적인 휴가라... 음, 아, 스킨다이빙은 어떠세요? 콘월 해안에서 2주 동안 스킨다이빙 한 주와 현지 어부들과 함께 상어 낚시 한 주를 포함한 모든 것을 제공합니다. 정말 좋은 조건입니다.
# 음, 그래...
# 음, 봐봐. 너 의사소통 기술을 좀 더 향상시킬 필요가 있어. Jasmine과 진짜 결혼하고 싶다면 말이야...
# Jasmine이야...
# 어. 그래...
# 음, 뭐, 알잖아...
# 그런데 왜 자꾸 그렇게 불안하고 긴장하게 되는 걸까요... 남편이나 아이들, 동료들한테도 막 화를 내려고 하고.
# 여기 신문에서 무료 휴대폰 광고를 봤거든요...
# 음, 200달러 해지 수수료가 있지만...
# 맞아, 태도라니... 어떻게 평가해야 할까?
# 아, 아니... 그냥 개인 판매자가 판매하는 차 얘기야.
# 뭐래... 향기 나 봐! 향수 샘플이에요!
# 좋네. 이 페이지의 배치가 마음에 드는데...
# 사이즈 36...인 것 같아요.
# 알겠습니다. 잠시만요... 사이즈 36 진한 갈색 가죽 벨트라... 아, 여기 있습니다. 남편분이 이걸 좋아하실 것 같으세요?
# 알겠습니다. 잠시만요... 사이즈 36 진한 갈색 가죽 벨트라... 아, 여기 있습니다. 남편분이 이걸 좋아하실 것 같으세요?
# 들으셨어야죠...
# 뭐라고요? 저는 그냥 이분하고 대화하고 있었을 뿐인데요...
# 저와 협조해 주시는 게 좋습니다, 아니면...
# 아, 세상에... 거의 잊을 뻔했네요. 바로 처리할게요.
# 들어보세요. 우리 프로그램의 정책을 알고 있잖아요. 변명 없이 놓친 시험은... 그리고 거짓말은 확실히 변명도 없고, 그러면 시험에서 0점을 받을 거예요. 예외는 없어요.
# 저 길 바로 아래야... 아마도.
# 할 수 있어. 가방 그렇게 무거운 거 아닌데... 음!
# 나 주방에 있어... 문 열고 들어와!
# 기다리시게 해서 죄송합니다. 잠시만 기다려 주세요... 총 금액은 3,107달러입니다.
# 음! 맥주, 테킬라, 그리고... 라임!
# 나쁘지 않네. 너 술에 대해 잘 아는구나... 그러면 살사에 뭐 들어간 건지도 아는 거겠지?
# 신선한 토마토, 초록 양파랑 하얀 양파...
# 아, 네, 문제가 좀 있어서요...
# 음, 손님...
# 아, 아, 음, 손님...
# 한 명이라구요? 하지만...
# 그러면 그렇게 출발하고 싶어요. 잠깐... 아내가 출근길에 저를 여기 내려줄 예정이에요. 대신 6시 30분 표로 예약해 주실 수 있나요?
# 잠시만요. Benjamin... 아, 여기 있네요. 일주일 동안 더블룸 하나 예약하셨네요. 여기 등록 카드입니다. 이 양식을 작성해 주실 수 있나요?
# 물론이죠. 하지만 제가 춤을 잘 추는 편은 아니라서...
# 그거 참 어려운 질문이네... 오타와가 더 예쁜 것 같아. 관광할 거리도 더 많아. 박물관이랑 갤러리도 많고.
# 문제 없습니다. 컴퓨터로 배송 조회 도와드릴게요. 이번 월요일 주문... 잠시만요. 아, 여기 있네요, 지난 목요일. 주문 번호 있으신가요?
# 나도 그래. 여기 있는 모든 것들이 나를 행복하게 해, 산과 물, 풀과 새들, 햇빛까지도...
# 아하, 아하...
# 네, 학교 다녀올게요...
# 아, 그리고 귀마개도! 이거 꼭 하고... 됐어, 이제 가도 돼.
# 왜, 얘야...
# 심한 두통이 있어요, 그런데...
# 정말? 고마워... 그래도 아직 배울 게 많아.
# 저기... 남성 신발 매장은 어디 있나요?
# 그래야 하는데, 선택지가 너무 많아. 성적이 좋아서 선택할 수 있는 학교가 많은데 그 다음엔...
# 응, 그렇지만 아주 유명해. 감독이 상도 받았대. 피터가 몇 달 전에 봤는데, 그 친구 말로는 부분적으로 폭력적이긴 하지만 아주 담담하게 표현됐대. 뭐랄까... 알지...?
# 응, 그렇지만 아주 유명해. 감독이 상도 받았대. 피터가 몇 달 전에 봤는데, 그 친구 말로는 부분적으로 폭력적이긴 하지만 아주 담담하게 표현됐대. 뭐랄까... 알지...?
# 그럼 공간도 협소하고 위생도 안 좋을 것 같은데...
# 그리고 손전등, 휴대용 라디오, 여분의 배터리, 작은 응급 키트, 치약 같은 개인 물품도 필요하지... 여벌 옷도 필요해.
# 글쎄, 친구가 요리에 관심 많아서, 그녀가... 아니, 내 친구가 수업 듣고 있어. 뭐, 중요한가?
# 결혼 클래스... 친한 여자 친구... 요리 교과서... 다 알겠다. 엄마 분명 좋아하실 거야.
# 결혼 클래스... 친한 여자 친구... 요리 교과서... 다 알겠다. 엄마 분명 좋아하실 거야.
# 결혼 클래스... 친한 여자 친구... 요리 교과서... 다 알겠다. 엄마 분명 좋아하실 거야.
# 정말 멋진 파티야, Joan. 음식도, 음료도, 분위기도... 모두가 즐기고 있어.
# 잠시만요... 이 사이트로 가세요. 링크 이메일로 보내드릴게요. 다운로드는 몇 분 안 걸려요. 설치 과정도 복잡하지 않아요.
# 손님, 저희는 저 멀리 언덕에서 가져온 천연 샘물만 제공해요, 그래서...
# 지금 경제 상황을 보면 낙관적이기 참 힘들어... 무역 적자는 커지고 소비는 줄어들고, 진짜 불황으로 향하고 있는 것 같아.
# 그럼... Stephen King의 이 소설은 정말 스릴러예요.
# 아니야. 그녀는 정말 좋은 사람이야...
# 맞아, 네 말이 맞아. 그런데 가끔 그녀가 너무 신경 써서, 아니... 그냥 나를 좀 옥죄는 것 같아. 나 혼자만의 시간이 좀 필요해.
# 알아...
# 잠깐만요, 적을게요... 네, 준비됐습니다.
# 광장... 오른쪽... 신호등... 그다음은요?
# 광장... 오른쪽... 신호등... 그다음은요?
# 광장... 오른쪽... 신호등... 그다음은요?
# 높은 건물... 그 건물은 어느 쪽에 있나요?
# 그런데... 그런데...
# 그런데... 그런데...
# 그리고 그녀가 MicroPower와 계약을 했어. Vince가 1천5백만 달러에 팔려고 했는데...
# 알겠어, 소원 빌게... 케이크 큰 조각 먹을래?
# 여보세요, Janet. 나야. 아, 잘 지내. 혹시 오늘 밤 Tom이랑 뭐 할 계획 없나 해서... 없어? 그럼 우리 집에 와서 브리지 게임 몇 판 할래?
# 이미 있는 구조에 추가하는 건데요. 새로운 걸 설치하는 게 아니잖아요...
# 어디 보자... '원하는 직무를 선택하세요.' 같은 건가?
# 서비스 빌딩에서 받을 수 있어. 내가 같이 가줄게... 자, 여기에 필요한 양식이 있어... 좋아, 성은 Hanks고, 다른 이름은 Andrew지. 네 학생 번호는 뭐야?
# 서비스 빌딩에서 받을 수 있어. 내가 같이 가줄게... 자, 여기에 필요한 양식이 있어... 좋아, 성은 Hanks고, 다른 이름은 Andrew지. 네 학생 번호는 뭐야?
# 잠깐만... 이 사이트로 가봐. 이메일로 링크 보낼게. 다운로드는 몇 분밖에 안 걸리고, 설치 절차도 간단해.
# 나도 동의해, 하지만 Sarah Tims는...
# 아, 맙소사! 이제 어떡하지? 내가 참 바보 같네... (손으로 머리를 쥐며)
# 잠깐만... 먼저 타이머 설정하고 버튼 누르면 돼, 어서 와.
# 치즈...
# 오. 카펫 좀 새로 깔아야겠네... 그 얼룩은 뭐야?
# 이쪽이야. 봐봐. 최신 가전제품 다 있어, 하지만...
# 냉장고 문이 좀 고장났어... 약간... 완전히 닫히지 않아서 박스를 대고 닫아놓고 있어.
# 냉장고 문이 좀 고장났어... 약간... 완전히 닫히지 않아서 박스를 대고 닫아놓고 있어.
# 어디 보자. 타일... 뭐라고? 창문은? 유리창이 없어?
# 2주라... 두통도 있나요?
# 최근에 일을 많이 했어요... 하루에 11시간 이상씩요.
# 음, 나는... 3년 전쯤 갔던 거 같아.
# 문제없어. 구운 칠면조, 샐러드, 푸딩... 뭘 준비할까 생각 중이야.
# 저는 변호사예요. 여기 면접 보러 왔어요, 그리고...
# 음, 흥미롭군요... 고급 초콜릿이라니, 어디서 생산되나요? 벨기에인가요?
# 아, 감사합니다. 음, 크리미하고 정말 부드럽네요...
# 네, 아주 독특한 맛이네요... 약간 매콤하고, 정말 독특합니다. 어떤 재료들이 들어있나요?
# 심판이 경기를 시작하라고 신호를 주었고, 이제 시작입니다. Ribero가 서브를 하고 중국이 재빠르게 받아냅니다. Chen이 세터에게 공을 넘기고... 와, 정말 멋진 세트네요!
# 모든 게 그런 것 같아, 매일 아침 같은 기차 타고, 하루 종일 같은 사무실에 앉아 있고, 같은 TV 프로그램 보고....
# 하지만 올해 경쟁이 심해서... 나만 아직 취업 못한 것 같아.
# 아니요. 사실 저는 상하이에 기반을 두고 있어요. 회의 때문에 이곳에 왔어요. T & D라니, 반가운걸요...
# 잠시만요... 은행 계좌 있으신가요?
# 그럼... 전화번호는 몇 번이야?
# 음, 들으니 이 주변에서 가장 잘하고 저렴한 베이비시터라고 하더군요, 그리고...
# 있잖아요, 신문에서 무료 휴대폰 프로모션을 봤는데요...
# 아니에요, 핸드폰은 무료예요... 50달러 우편 환불받으면요.
# 해지 수수료가 200달러 있긴 한데...
# 맞아... 우리는 테이블에 음식, 과일, 음료를 내놓고 배고픈 귀신들에게 바쳐.
# 아니! 그래서... 할로윈도 일종의 '귀신의 달' 같은 느낌이야.
# 아마 네 말이 맞아. 그런데 그렇게 간단했으면 좋겠는데... 어떻게 하면 계속 불안한 걸 멈출 수 있을까?
# 아이고! 너무 오래돼서 까먹을 뻔했네. 잠깐만... 네, 제 일정표에 있어요.
# 맞아, 근데 멋진 작은 요소들이 많았어 - 음악, 조명, 카메라가 계속 움직이는 것도... 전에 이렇게 흥미로운 영화는 본 적이 없는 것 같아.
# 나도 여러 가지 생각이 들었어. 그리고 중간에 슬픈 장면이 하나 있었어...
# 저기... 주스 한 잔 어때?
# 아니, 차가 좋아. 내가 좋아하는 컵에 따라줄래? 아마 씻었을 텐데...
# 아, 맞아. 그게, 네 머그컵에 대해서...
# 내가 찾을게... 꽃무늬 접시들 다 어디 갔어? 그리고 아빠의 야키스 머그는?
# 그런데 여기서 휴가 중인데 배가 너무 아파요...
# 최대한 빨리 보면 좋겠어요. 30분만 더 기다리면 이 통증 때문에 기절할 것 같아서...
# 좋아요, 보자... 음, 수명선이 긴 게 좋고, 애정선도 강하네요...
# 좋아요, 보자... 음, 수명선이 긴 게 좋고, 애정선도 강하네요...
# 어렵긴 한데, 아, 사업에서 잘될 것 같아요. 당신의 야망이 큰 도움이 될 거예요. 그런데...
# 음, 그게...
# 아, 그래. 그거... 좋네.
# 글쎄... 보통 때라면...
# 글쎄... 보통 때라면...
# 사실은...
# 미안해, 까먹었어. 아, 잠깐...
# 음, 뭐랄까... 뭘 알고 싶어?
# 보자... Good Morning, Vietnam, Dead Poet's Society, The Fisher King... 세 번이지, 맞지?
# 보자... Good Morning, Vietnam, Dead Poet's Society, The Fisher King... 세 번이지, 맞지?
# 찾아볼게.  파란색, 초록색, 분홍색, 검정색... 그리고 하얀색. 여기 있어.
# 스폰서라는 게 어떤 걸 말하는 거죠? 스폰서십이 얼마나 효과적인지 잘 모르겠네요...
# 스포츠, 의학, 교육... 좀 무작위 같지 않나요?
# 잠깐만... 6시 15분에 시작하네. 근데 처음부터 보려면 시간이 좀 빠듯할 것 같아. 뉴 스테이트 시네마에서 하는 액션 영화는 어때? 6시 50분에 시작하거든. 아니면 UME 시네마에서 7시에 하는 것도 괜찮겠어. 성룡이 나오네.
# 그게... 잘 모르겠어. 근데, Connie, 넌 그러지 않겠지?
# 아, 물론이지. 어떤 일이 있어도 경기는 절대 놓치지 않아. 내 여자친구는 내가 중독됐다고 그래. 사실, 여자친구랑 경기를 선택해야 한다면... 아마도 미식축구를 선택할 것 같아.
# 브라운이라... 좀 밋밋하지 않아?
# 모든 것 때문에 그래. 매일 아침 같은 기차 타고, 하루 종일 같은 사무실에 앉아 있고, 똑같은 프로그램 보고...
# 나도 즐거웠어. 오늘 밤 정말 아름다워 보여! 이 밤이 끝나지 않았으면 좋겠어. 너한테 할 말이 있어...
# 그럼 특별한 사람을 찾으면 선물하세요... 그리고 이 반지도 잘 어울릴 거예요.
# 아, 완전 금발이야. 꽤 짧은 머리인데...
# 아니... 아니야. 너 다른 사람 생각하는 것 같은데.
# 또 뭐가 있을까? 그녀는... 아주 동그란 얼굴에 큰 입을 가졌어. 웃을 때는 얼굴이 다 입 같아.
# 차고 세일... 혹시 차를 구경하는 데 아니야?
# 거북이? 뭐든지 간에... 봐, 물질의 창조에는 입자와 반입자의 불균형만 있으면 돼. 적어도 수학은 그렇게 말해.
# 증거는 있지! Edwin Hubble 알아? 그는 20세기 초에 우주의 물질 이동을 처음으로 측정한 과학자야. 그래서 확장하는 우주에 대한 개념을 발전시켰어. 그게 어디서 확장할까? 글쎄, 빅뱅에서... 알겠지!
# 어디 보자. 노트북, USB, 볼펜, 연필, 노트, 안경, 휴대폰, 충전기, 수분크림, 설명서... 오, 너무 많다. 출장 가는 것도 아닌데.
# 음, 그래, 알겠어. 하지만...
# 저는 스테이크랑 감자튀김 할게요. 저기... 와인 리스트 좀 볼 수 있을까요?
# 주 4회 가고 싶지만 게을러서... 지난주에는 한번밖에 안 갔어요.
# 좋아... 뷔페랑 케이크는 어때? 너희 엄마가 케이터러랑 얘기하셨어?
# 언니, 안녕. 네가 원했던 DVD를 주려고 잠깐 왔는데... 어, 우와!? 이거 다 어디서 난 거야?
# 나 샀어. 내 새 오락기구 어때? 그리고 이 와이드스크린 TV...
# 이걸로? 봐봐... 설마 아빠 신용카드 또 쓴 거 아니지?
# 들어봐, 요즘은 시대가 바뀌었잖아. 신용카드로 신용도 쌓고, 지출도 관리할 수 있고, 현금으로 못 사는 것도 살 수 있어... 최근에 산 비행기 표처럼.
# 아 맞다, 나 룸메이트랑 방학 동안 하와이에 가기로 했거든. 그리고 당연히 새 옷도 필요해서...
# 듣고 싶지 않아. 학생 신용카드가 어떻게 지출 관리하는데? 완전 구멍 났구만. 아무튼 학생 신용카드는 충동구매만 부추기잖아... 보니 알겠어. 그리고 이자율이 엄청 높아서 결제 못 하면 더 올라!
# 아. 신용카드에는 신용 한도가 있어...
# 아, 그건 아니야. 아무튼...
# 나 100개 넘는 채널이 있는 디지털 케이블도 봐. 아, 그리고 네 생일선물. 새 MP3 플레이어...
# 제가 측정해드릴게요... 사이즈 6이시네요. 어떤 색상의 모자를 원하세요?
# 그래, 그거 좋네요. 진짜 어색하다... 뭘 골라야 하지? 그녀 사이즈가 뭐지?
# 그냥 빨리 아무거나 고르고 나가자. 음, 이 둘로 할게요. 정말 창피하다. 빨리 끝내고 싶어. 그녀가 꼭 고마워하길 바란다...
# 오늘 아침에 부모님한테서 편지가 왔어. 가족이 많이 그리워. Molinas 가족도 나한테 잘해주고, 너희 가족이랑 함께 있는 거 정말 좋은데... 가족 사진이 같이 온 편지를 보고 눈물이 나더라.
# 이런 양식들이 참 어렵네... 그래도 곧 익숙해질 거야.
# 그러니까, Gregorio Zuttlemisterburger라고... 아, 그냥 'Grip'이라고도 불러.
# 그리고, Brad Pitt도 있어...
# 이제 뭔가 아는 사람이 나오네...
# 그렇구나... 일요일에는?
# 그냥 제가...
# 네, 너무 잘 기억해요. 하지만 저는...
# 그럼... 버스 서비스를 어떻게 개선할 수 있다고 보세요?
# 아, 죄송합니다. 잠시만요...
# 음, 솔직히 말하면, 일이 너무 바빠서 웹 서핑할 시간이 별로 없어. 생각해보자면... 일주일에 두세 번 정도, 한 번 할 때마다 두세 시간 정도 접속하는 걸까?
# 맞아요! 미스...  미스...
# 맞아요! 미스...  미스...
# bulldog123이라... 그게 다예요?
# 'You ain't nothing but a hound-dog...'
# 내일 오후요... 사실 제가 내일 오후에 코멧 씨와 약속이 있습니다. 장 씨를 만나기 위해 코멧 씨와의 약속을 취소해야 할 것 같네요.
# 잠시만요, 확인해 보겠습니다. 내일 오후... 네, 내일 오후 2시부터 시간이 됩니다. 괜찮으신가요?
# 그리고 우리 어릴 때 사진들을 모아 각자 콜라주로 만들기로 했잖아...
# 맞아... 아, 안돼! Marcus가 삼진 당했네! 이제 두 아웃이야.
# 오, 첫 스트라이크... 괜찮아, 아들! 침착하게 해!
# 이번 거다... 두 번째 스트라이크... 아, 자기야, 방금 전 공에는 정말 늦었어!
# 이번 거다... 두 번째 스트라이크... 아, 자기야, 방금 전 공에는 정말 늦었어!
# 지금... 지금... 미안해요, 너무 긴장해서요. 저희는 컬러 홀 2층 211호에 있어요.
# 지금... 지금... 미안해요, 너무 긴장해서요. 저희는 컬러 홀 2층 211호에 있어요.
# 그녀의 이름은...  아니타 리베라에요. 제 이름은 로렌스 클락이고, 저는 이 대학교의 교수예요.
# 나도 그래. 고기도 거의 다 됐어. 잠깐만... 아!
# 아, 그런 게 아니야. 그냥 이메일 주고받는 정도야, 진짜 아무것도 아니야. 게다가 고민 중이기도 해, 점점...
# 아, 그런 건 기억도 안 나. 맞다, 내 생일에 장난으로 한 서른 개 넘는 방을 돌아다녔어. 그때 거기 있었고 대화를 시작하게 됐지...
# 잊어. 개인적인 건 얘기 안 해서, 이름이나 직업, 사는 곳조차 몰라. 그래서 만나는 걸 그만두는 건 정말 쉬울 거야, 왜냐면 난 전혀...
# 그리운 옛날 얘기 같은 상담 사연도 많고 말이야...
# 그래서 네가 그런 괴짜구나...
# 뭐래... 이거 냄새 맡아봐! 향수 샘플이야!
# 좋다. 야, 나 이 페이지 레이아웃 마음에 드는데...
# 저희 형이 옆 가게에서 일하는데 그분은...
# 다시 말씀드릴게요... 지금은 들리세요?
# 잠깐만... 어, 하나는 창가 자리, 하나는 통로 자리야.
# 지하철이요? 근데 호텔 근처에 지하철역이 있나요? 하루에도 여러 번 회의장과 호텔을 오가야 하거든요...
# 아, 글쎄요... 왼쪽으로 돌고 쭉 가세요.
# 웹사이트라... 그쪽에 대한 책을 읽은 기억은 없네요.
# 맞아. 도시에서 다닐지, 시골에서 다닐지, 큰 학교, 작은 학교, 공립, 사립... 결정해야 할 게 많네.
# 응, 준비할 게 너무 많아. 웨딩 사진, 웨딩 드레스, 케이터링, 교통, 호텔 등등...
# 하하... 농담도 재미없어. 그 말은, 우리 사랑하는 사이를 끝내야 한다는 거네.
# 가장 큰 장점은 저렴함이라고 생각해. 필요한 건 라켓, 탁구대, 가벼운 셀룰로이드 공뿐이야. 탁구대는 대개 공공 휴식 공간, 예를 들면 후미진 방이나 야외 놀이터에 있어...
# 음, 잘 모르겠네요. 시간이 별로 없어서...
# 저는 변호사이고, 직장 내 사고를 전문으로 하고 있어요. 중요한 면접 때문에 이 도시에 왔는데...
# 걱정하지 마세요. 조정 좀 하고 있었어요. 됐습니다. 좋아요...
# 진정하세요. [가장 좋아하는 단어군요...]
# 좋아요, 이제 머리 말리고, 젤 좀 바르고, 드라이기로 스타일링하고... 짠!
# 음, 저희는 모든 작업에 대해 환불 보장을 해드리는데, 만족하지 않으시면...
# 만족한다고요? 전혀 아닙니다. 매니저랑 얘기하고 싶어요... 지금!
# 죄송하지만, 매니저가 휴가 중이고 제가 대신 맡고 있어서요...
# 음, 옆집에 제 동생이 있는데요, 완전 패키지를 제공해요...
# 세련된 여행가라... 아마 가이드북에서 처음 발견한 곳을 고른 거겠지만요.
# 좋아요, 조금만요. 아야- 포크를 떨어뜨렸네요. 잠깐만요...
# 아, 죄송하지만 이번 주말에는 다른 일정이 있는데요. 그래도 한번 생각해볼게요...
# 아, 맞아. 그런데 무슨 일이 일어나는지 잘 모르겠어... 지금 누가 이기고 있는 거야?
# 음, 아니요. Linda가 그런 얘기를 한 적은 있지만... 고마워요. 하지만 다시는 저에게 그렇게 말하지 마세요.
# 우리가 근황 얘기 나누고, 일이나 가족 얘기하는데, 갑자기 매트가 자기 의자 밑으로 쥐가 달리는 걸 보고 완전 놀란 거야! 막 소리 지르고 난리였어...
# 응, 더 웃긴 건 뭐냐면, 의자 위로 점프해서 소녀처럼 비명을 지르는 거야. 너도 있었으면 진짜 웃겼을 거야! 모두가 쳐다보고 웃었어... 정말 웃겼지!
# 뭔가를 부딪혔어 아니면...
# 아, 그래. 가자... 아, 이런! 시계 안 가져왔어.
# 가장 좋은 회사라... 그렇구나. 요즘 회사가 많은데 어떻게 그렇게 탄탄한 위치를 잡았지?
# 그냥 약간 긴장돼. 모든 걸 쏟아붓고 있는데, 그리고 나서...
# 라이언 말로는 거기 계속 있고 싶대. 어떤 과일 플래터 디자인하는 여자한테 반한 것 같아...
# 아니요... 여기 북극 작업장에서 만든 거예요!
# 잠시만요... 뉴욕으로 가는 기차라... 여기 있네요. 매일 운행하고 일요일은 제외하고 10시 30분, 12시 20분, 15시 10분입니다.
# 잠시만요... 뉴욕으로 가는 기차라... 여기 있네요. 매일 운행하고 일요일은 제외하고 10시 30분, 12시 20분, 15시 10분입니다.
# 그리고 거기 식당들이 정말 좋아... 그런데 조금 비싸.
# 저기요...
# 하지만 저는...
# 이번 휴가 정말 기대했는데... 크리스마스 때 바베이도스에서 3주간 따뜻한 날씨, 바다, 햇빛을 즐기는 거.
# 근데...
# 네, 잠시만요... 아니요, Smith 씨는 오늘 아침에 체크아웃하셨어요.
# 아니... 그게 그 뜻이 아니었어. 그런 의도가 아니었어. 마사가 네가 어디 있냐고 물어봤을 때, 농담으로 네가 사라랑 데이트 중이라고 했던 거야. 마사가 너랑 사라가 그냥 친구라는 거 알고 있는 줄 알았어.
# 네, 사실 당신의 매니저로부터 연락이 왔고, 그가...
# 저기... 오른쪽 이웃방인 것 같은데요.
# 어디 보자... 음.. 바람과 함께 사라지다가 토요일 밤에 여섯 군데 영화관에서 해.
# 한번 맞혀 볼게. 분명 멀리 있는 멋진 곳일 텐데... 이집트?
# 어! 어디 가는 거야...?
# 칠면조요...
# 아, 저는 사라와 얘기하러 왔어요...
# 어, 제 이름이요? 저는 닉이에요...
# 음. 브라운스빌에서 왔어요. 왜 묻는 거죠...
# 좋아한다고요? 무슨 말이에요? 저는 한 번밖에...
# 알았어야 했는데... '못 찾을 리가 없어'라고 하면 꼭 못 찾게 되더라.
# 잠시만요... 아, 15,880NT네요. 할인을 적용하면 합계가 12,704NT로 됩니다. 여기 무료 곰인형과 무료 속옷, 카드 신청서가 있어요.
# 하하... 여자들 참 그렇다니까!
# 하지만 여보, 난 당신이 정말 최고라고 생각해. 아무것도...
# 물론이죠. 우선, 이전 모델은 화면이 꽤 작아서 한 번에 많은 정보를 볼 수 없었어요. 그래서 새로운 모델에서는 화면을 훨씬 더 크게 만들었고...
# 아, 다양한 용도가 있고, 그 부분은 조금 이따가 자세히 설명드리겠습니다. 먼저, 하고 싶은 말이...
# 응, 나 그거 꽤 잘해. 봐! 여기 이렇게...
# 아니, 아니야. 있잖아, 솔직히 네가 두 가지 동시에 하려는 게 불편해... 그리고 그건 법에 위반이야.
# 안 돼, 안 돼. 문자가 거의 다 끝났어... 잠깐만.
# 영어 수업 성적이 걱정돼요. 정말 A를 받고 싶은데...
# 알겠습니다. 이 양식을 작성하시고 여기에 코드를 입력해 주세요... 다시 입력해 주시고요. 돈이 이체되었는지 확인해보겠습니다. 네, 거래 성공적입니다.
# 야, 나 지금 전화 못 받아. 그냥 메시지 남겨 ... [삐-]
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# Greg, Greg. 너 대체 어디야? 이봐, 난 지금 큰일 났어, 그리고 이건 다 네 잘못이야! 네가 Cindy가 싱글이라고 했잖아! 정말 틀렸더라! 네 여동생이 7피트짜리 고릴라인 Butch랑 헤어진 지 얼마 안 됐다고 얘기해줬어야지. 그 남자 정말 거대하더라. 내가 그녀를 집 앞에 데려다주는데 그가 나타나서 거의 나 목 졸릴 뻔했어. 그리고 그의 맹수 같은 개 말이야, 경고라도 했어야지. 거의 내 팔 물어뜯을 뻔했잖아. 겨우 도망쳐 나왔는데, 그 미친놈이 괴물 트럭 몰면서 쫓아오더라고. 그리고 네가 차에 기름 없다고 말해줬어야지, 도로 중간에 멈춰버렸고 지금 어두운 주유소 화장실에 숨었어. 전화 좀 받아 ... 어서 받아 ... 아, 안돼 그 녀석 소리 들려 ... 그리고 네 전화 꺼질 것 같아 ... 아 진짜 ... 이게 이렇게 배터리 못 받치는 거였으면 말해줬어야지 ... 아 정말 ... 나 그냥 집에서 빨래할걸 ... 네 황당한 아이디어 듣고 나간 게 잘못이었어 ... Greg, Greg? 어디 있는 거야?
# 우리 모두 그런 거 아니야? ... 아, 그리고 네 사촌은 선물용품을 파는구나?
# 저지방으로 부탁해. 고마워... 아, 이런. Janna, 정말 미안한데, 나 가봐야 해.
# 국립미술관에 가려고 해요, 그리고...
# 너무 문제를 많이 일으켜서 말이야. 고치는데 돈도 너무 많이 들고... 차 값보다 많이 쓰고 있었거든. 좀 안타깝지만 팔게 됐어. 실제로 팔 때 손해가 이중으로 컸지.
# 그리고 침대 정리하고 방에 있는 장난감 다 치우고...
# 모르겠어...
# 잠깐만, 저건 뭐야...? 도넛? 유기농 도넛이야, Kelly?
# 그래, 학교 다녀올게...
# 아... 그리고 귀마개도! 이거 끼고 나가... 자 됐어.
# 왜, 아가...
# 그리고 마지막 경기에서는 우리 팀이 훨씬 앞서고 있었는데, 막판 3분 남기고 상대팀이 역전해서 이겼어. 완전 수치였지. 우리 팀은 야유를 받았어. 내 말은, 우리 선수들 눈에 해가 들어왔다고...
# 아, 그렇군요...
# 어디 보자, 노트 3권, 연필 5자루, 지우개 2개...
# 잠깐만... 어, 하나는 창가 자리, 하나는 복도 자리야.
# 네 말이 맞을지도 몰라. 어떻게 해야 할까? 옛날엔 이렇게 짜증내지 않았는데...
# 아직도 중국 사람들이 프라이버시를 어떻게 생각하는지 궁금해. 중국에 프라이버시가 없다는 말은 아닌데...
# 알았어. 그러면... 대상에게, 나는 쓰고 있습니다.
# 그건 너무 편안한데! 어느 정도는 예의를 보여야 해. 'Dear Ms. Cooper, I'm writing to confirm...'으로 시작하는 게 어때?
# 잘했어...
# 'The final costing, including advert design and production, comes to forty-five thousand six hundred RIB. We want payment ten working days before publication or we will cancel the ad. Thanks for...'
# 저기요, 죄송한데요... 제 이름은 Rachel이에요. 여기 새로 왔는데 부탁 하나 드려도 될까요?
# 아, 웹사이트라... 그 부분은 제가 익숙하지 않네요.
# 뭐, 여기 온 김에...
# 다이어트를 하거나 적어도 엄마가 해준 음식을 너무 많이 먹지 않는 게 좋겠어. 그리고...
# 그래, 좋다! 그럼...
# 완전 반했지. Zina가 WebTracker를 어떻게 잘 해결했는지 보고 나서... 근데 너도 그 얘기 다 알지?
# 모르겠어... 혹시 차 잠깐 빌려줄 수 있어?
# 최악인 건 인플레이션이 부유층보다 서민층에 더 큰 타격을 준다는 거야. 장기적으로 실업률도 증가시키고. 어떻게 해야 경제가 다시 활기를 찾을 수 있을지 모르겠어...
# 나한테는 좋은 해결책이 있어... 새로운 피가 필요하다고 생각해! 대통령을 바꾸고 새로운 지도자를 선출해야 해.
# 종업원! 매니저와 이야기하고 싶어요... 가능하면 지금 당장요.
# 진짜 고급스러워 보인다... 매일 새 렌즈라니...
# 진짜 고급스러워 보인다... 매일 새 렌즈라니...
# 아, 안 그래도 되는데...
# Hugh 생각나네요. 대부분의 사람들은 그가 조금...  특이하다고 생각했죠. 그 사람 지금 뭐하는지 아세요?
# 음, 내가 너 좋아하니까... 90달러.
# 잠시만요... 죄송하지만, 금연 방이 더 이상 없어요. 그래도 오늘 밤 방 요금은 받지 않겠습니다.
# 중국 사람들은 프라이버시를 어떻게 생각하는지 아직도 궁금해. 프라이버시가 없다는 건 아닌데...
# 그래, 약을 좀 줄게. 한 번에 하나씩, 하루에 세 번 먹고, 3일 후에 다시 와봐. 그래도 나아지지 않으면...
# 어, 그래요? 놀랍네요. 어디 보자... D 0411 우리 강아지 생일. 네, 확실히 제 주차 공간 맞아요!
# 잠시만 기다려주세요... 여기 중국 돈입니다. 3,220 위안 맞는지 확인해 보세요. 이 환전 영수증을 꼭 보관하세요. 나중에 필요할 수도 있습니다.
# 응, 알아. 가자. 적당한 걸 찾을 수 있을 거야. 뭔가 오래된... 역사적인 걸 사야 해.
# 어디 보자. 신생 회사에서 매니저 구하네. 조직 능력 필수고, 경력 우대래. 그리고 Susan Lee에게 연락하라고 하네. 음, 잘 모르겠네...
# 알았어. 1950년대 중반쯤에는 경쾌한 장르가 더 진지한 주제를 다룬 영화들과 경쟁했어. 모든 시대에 걸쳐 만들어진 한 가지는, 음, 그건...
# 뭐, 뭐, 변명하는 건 아니지만, 몇 번은 날씨가 안 좋았고, 그리고... 그리고 한 번은 내가 안 보고 있는데 물고기가 내 낚싯대를 물속으로 끌고 갔고.
# 좋아, 내가 보여줄게. 그 낚싯대 줘봐. 보여줄게. 그냥 미끼를 저쪽으로 던지면... 완벽해.
# 와, 잠깐, 잠깐, 잠깐, 잠깐. 그럴 리가... 아니, 아니, 아니.
# 음, 싫어...
# 아, 알겠습니다. Nelson 씨 맞죠. 다섯 명 방이고...
# Charles Nelson. 19일에 1인실...
# 음, 지금 밤에는 방이 없습니다. 시내에 컨벤션이 있어서... 네, 방이 없어요.
# 아니요. 하지만 제 친구 몇 명이 여기서 직장을 구했거든요. 그래서 저도 한번...
# 네, 알겠습니다. 가능한 직장이 있는지 찾아보는 게 좋을 것 같네요. 그럼...
# 저기... 몇 개 좀 살 수 있을까요?
# 저한테서 산다고요? 근데... 프랑스 담배 싫어하시잖아요!
# 응, 처음엔 정말 어색했어. Bill이 강등되고 사직한 후에는 사무실 분위기가 마치 장례식장 같았어! 관리부에서 내게 그 자리를 맡으라고 했을 때 사람들이 날 배신자라고 생각할까 봐 겁났어...
# 음, 안타깝지만, 그렇네. 그 포렌식 검사 결과에 대해 안 좋은 소식이 있어... 결과가 없을 거야.
# 정말 얘기하고 싶지 않지만, 우리에게 유리한 증거들이 실험실 화재로 다 불타 없어졌어. 남은 게 하나도 없어. 정말 미안해...
# 음, 회사에서... 뭐랄까, 60명에 대해서 얘기한 것 같은데... 그리고 당신도 그 중 한 명일 수도 있다고... 그런 것 같아.
# 음, 회사에서... 뭐랄까, 60명에 대해서 얘기한 것 같은데... 그리고 당신도 그 중 한 명일 수도 있다고... 그런 것 같아.
# 음, 회사에서... 뭐랄까, 60명에 대해서 얘기한 것 같은데... 그리고 당신도 그 중 한 명일 수도 있다고... 그런 것 같아.
# 좋아. 먼저...
# 좋아. 알았어... 아마도.
# 봐봐... 알잖아!
# 아... 그러니까, 내 프로젝트에 도움 좀 줄 수 있을까 해서. 그냥 책이랑 프로젝트 계획만 가져오면 돼. 금방 끝날 거야... 우리, 음.
# 심판이 경기 시작 신호를 주고, 이제 시작합니다. Ribero가 서브를 하고 중국이 재빠르게 받아냅니다. Chen이 세터에게 공을 넘기고... Chen의 정말 멋진 세트네요!
# 알겠어. 음, 이 영화 또 재방송이야. 얼마나 많이 봤는지 모르겠어. 광고 또 나오고... 그리고 토크쇼 재방송... 아, 이 쇼는 진짜 별로야, 보지 마.
# 알겠어. 음, 이 영화 또 재방송이야. 얼마나 많이 봤는지 모르겠어. 광고 또 나오고... 그리고 토크쇼 재방송... 아, 이 쇼는 진짜 별로야, 보지 마.
# 음, 좋긴 한데, 영어 수업 때문에 읽어야 할 게 있어서...
# 브라운이라... 좀 칙칙하지 않아?
# 맞아, 했는데 예상했던 문제들이 아니었어. 답하려고 노력했는데...
# 근데 저 사람이 내 이름이나 사는 곳 알면 어떡하지...
# 그냥 착하고 외로운 사람일 수도 있지 않을까...
# 물론, 여기 있어...
# 보자, '회의 전에 관련 자료를 저희 사무실로 보내주시면 감사하겠습니다.'라고 쓰여있네... 어, 이 편지 외에 더 보내진 건 없었어?
# 이 편지에 '검토를 위한 안건 복사본을 동봉하였습니다.'라고 적혀있는데... 봉투 안에 아무것도 없어...
# 이 편지에 '검토를 위한 안건 복사본을 동봉하였습니다.'라고 적혀있는데... 봉투 안에 아무것도 없어...
# 어디 보자... 한 500달러 정도로 가입하면 될 것 같아요.
# 아, 비밀번호를 입력하라고 하네요. 알겠어요, 할 수 있어요...
# 그렇구나...
# 요즘 경영진이 많이 바뀌고 있어. Bill이 은퇴하고 부서 재편성까지 하면서, 관리자 인원의 1/3 정도를 잃은 상태야. 정말 빠르게 줄어들고 있어...
# 맞아, 우리에게는 리더십이 필요해. 하지만 우리가 필요 없는 건 너무 많은 리더들이지. 그런 말도 있잖아, 수장은 많고 인디언이 부족하다고...
# 알겠어... 네 말도 이해해.
# 좀 무서워서. 달콤하긴 한데 꽤 독한 것 같아... 세 잔 마시면 취할 것 같아!
# 왜 우리가 새로운 시장을 열고 기존 시장을 동시에 개발할 수 없는지 모르겠어... 고객층을 늘리고 브랜드를 발전시키는 것 모두 중요하다고 생각해.
# 음, 오늘은 돈을 많이 쓰지 않으려고 했는데...
# 맞아요, 디스코는 사람들이 쉬지 않고 녹음된 음악에 맞춰 춤추는 곳이죠...
# 그럼... 디스코는 그 음악을 가리키는 말이고, 디스코는 사람들이 춤추러 가는 장소를 말하는군요. 그리고 브레이크댄스는 전혀 다른 종류의 것인가 보네요.
# 음, 잘 모르겠어... 좋은 보모 찾기가 어렵잖아. 이전에 했던 일 경험도 따져봐야 하고, 맡길 책임도 잘 생각해야 하니까. 아이들과 어떻게 지내는지도 중요하고. 그래도 도와줄 사람 있으면 좋겠어.
# 좋은 생각이야, Eric! 멋질 것 같아. 내 일정 좀 볼게... 목요일부터 일주일쯤 쉬면 되는데, 그 전에는 안 돼.
# 나도 내 일정 좀 볼게...응, 괜찮아.
# 지금 거의 생각났어...생각났다. Strawberry River Inn이야.
# 여기, 직접 봐. 정말 이상하네! 내가 예전에 겪었던 거랑 거의 똑같아...
# 우와, 네 말이 맞아! 빅이라는 사람한테서 온 거네. 그 사람이 누구인지 궁금해...
# 저도 최선을 다하고 있어요, 할머니...
# 아, 시작이네...
# 아니요, 'excuse me' 혹은 'excuse me, please'라고 말해요. 그리고 다른 사람의 말을 끊을 때도 'excuse me'를 사용해요...
# 이쪽으로 오세요. 방은 위층에 있어요... 여기에요.
# 잠시만요... 네, 하나 남아있네요.
# 카페오레, 카페라떼, 카푸치노, 카페모카... 다 헷갈려!
# 그랬어... 이 훌륭한 아이디어들을 다 실천할 수 있으면 좋겠어.
# 알겠어요, 고마워요...
# 좋네요. 그럼 발진을 한번 볼게요... 생각보다 심각하진 않네요. 연고를 처방해드릴게요. 발진이 며칠 안에 좋아지지 않으면 다시 오세요. 다른 증상은 없으신가요?
# 두통이 심한데요...
# 네, 한 시간쯤 전에 도착했어요. 그런데...
# 잘 모르겠는데, 잠시 제 스케줄을 확인해볼게요... 아, 괜찮네요, 그때 시간 돼요.
# 안녕, Isabelle...
# 그럼요, 잠시만요... 여기 흰색과 연노랑색입니다, 손님.
# 응, 있어. 지역 신문에서 주최한 작은 대회에서 1등 했어. 대회 주제가 '학교란...'으로 문장을 완성하고 포스터를 디자인하는 거였어.
# 한 가지 더 있어. 테일러 스미스 봤어? 상태가 별로 안 좋아 보이던데. 듣기로는 걔가...
# 아, 그러니까... 늦잠을 자버렸어요.
# 지갑을 잃어버렸어요, 그리고...
# 오늘 아침에. 그러니까...
# 잠시만요...
# 음, 부분이 2개, 아니 3개야. 먼저 데이터 수집 방법에 대해 에세이를 써야 해. 그리고...
# 어디 보자... 네, 열이 꽤 높네요.
# 빌리...
# 네, 비자 카드예요...
# 오늘 여기 온 이유 중 하나는... 음, 두 가지 부탁을 드리고 싶어서요.
# 그리고 두 번째는... 음, 정상적인지 모르겠어요.
# 어디 보자. 노트북, USB, 볼펜, 연필, 노트, 안경, 휴대폰, 충전기, 보습제, 노션... 아, 이건 너무 많잖아. 출장 가는 것도 아닌데.
# 발만 따라서 움직이면 돼. 왼쪽으로 쓸고, 오른쪽으로 쓸고... 그래! 바로 그거야!
# 잠시만요... 네, 하나 남아있네요.
# 나는 괜찮지만, 그녀가 두 가지 일 때문에 바쁘잖아, 그래서 부탁하기가 좀 그래. 그리고... 야, 너 오트밀 쿠키 좀 만들어봐. 그리고 그 새로 이사 온 Susan한테 부탁해보면 어때? 아, 그녀는 정말 매력적이잖아!
# 아냐, 그녀에겐 부탁 못하겠어... 전화번호도 모르는 데다...
# ...
# 맞아. 파란 하늘, 햇살, 군침 도는 음식, 수백 년 된 성곽들...
# 그토록... 응, 다들 알지. 그래서 결심하고 나선 어디로 갔어?
# 원래 정원을 가꾸며 채소랑 꽃을 조금씩 키웠었거든. 샐러드용 채소, 당근, 완두콩, 콩, 과일 조금, 장미 같은 것들... 그래서 소규모 농장을 생각했는데 부동산 가격을 보고 나선 포기했어. 그런 돈은 없더라고.
# 이게 슈퍼볼보다 더 큰 대회야, 친구! 32개 팀이 매 4년마다 그 트로피를 위해 싸우잖아. 처음엔 그룹 스테이지로 시작해서...
# 네, 잠시만요... 네, 도착했습니다. 금액은 51,998 미국 달러이고, 중개 은행에서 12달러가 차감되었습니다.
# 나도 그건 괜찮아. 나중에 부자가 되어 필요 없게 되면 좋겠지만, 혹시라도 필요하게 되면...
# 그러면... 바에 가서 노래방 노래 부를래?
# 안 될 것 같아... 미안해.
# 좋아, 여기서 왼쪽으로... 아 잠깐, 오른쪽이었어. 빨리 좀 가!
# 걱정 마, 그냥 운전이나 해. 아, 신호 바뀌겠다... 밟아!
# 알겠어. 여기서 오른쪽. 이 시간에 고속도로는 막힐 거야... 옆길로 가자. 아, 비켜! 비켜!
# 여기야, 지름길 알아... 여기로 내려가서 애쉬번 하이츠로 가자. 빨리빨리! 저 여자 조심해!
# 저기, 이건 강도 사건이야. 이 가방에 돈을 다 넣어... 당장.
# 내... 주머니에... 봐봐.
# 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서 ... 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서 ... 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# 알겠어요, 알겠어요. 그렇게 흥분할 필요 없어요. 어디 봅시다. [어서!] 어디 보자... 여기 몇 달러와 [어서 ... 서둘러!!] 몇 장의 10달러 지폐... 몇 개의 동전. [어서!] 어, 여기 1935년 오래된 페니가 있네요. 이런 건 오랜만에 보네요.
# 작은 구멍... 큰 구멍. 상관없어. 네 양말에라도 넣어.
# 알겠어요. 하지만 지금 돌아서는 게 좋을 것 같아요. 저기 좋은 경찰관들이 당신과 얘기하고 싶어 하시는 것 같아요... 뭐든지.
# 아, 글쎄...
# 저희에게 꽤 멋진 실크 이브닝 드레스가 있습니다...
# 네. 여기 사인해주시면...
# 저희... 저희는 종이 캥거루도 만들었어요.
# 그리고... 엄마가 너희 중학교에 갔다고 하시던데.
# 이자벨라, 안녕...
# 로건! 대체 여기서 왜 숨어있는 거야? 흰 모자! 설마 네가 그 사람일 리가... 사실이 아니기를!
# 설명할게. 상처 주려던 건 아니었어...
# 최근에 사고 난 적 있어요... 아! 이 차를 알아요!
# 스마트한 선택 같은데... 좀 지루하겠네.
# 나 아직 모르겠어... 근데 우리 2학년 때까지 전공 선언 안 해도 되니까 시간은 있어! 아차, 수업 늦겠다. 나 갈게!
# 그러니까... 하나님이 우주의 창조자라고 하거나, 성경, 예수 그리스도 같은 것요...
# 그러니까... 하나님이 우주의 창조자라고 하거나, 성경, 예수 그리스도 같은 것요...
# 제가 좀 볼 수 있을까요? 세부사항을 확인해볼게요... 맞네요.
# 알겠습니다, 손님. 등록해 주시겠어요? 이 카드에 성함과 주소를 적어주세요... 감사합니다. 이 짐이 손님 것인가요?
# 그렇겠지. 근데 있잖아... 너 가기 전에 한 번 만나고 싶어. 저녁 같이 먹으러 갈래?
# 아니... 토요일 밤은 시간 돼.
# 웃지 마, 그런데 온라인 음악 메일링 리스트로 정말 괜찮은 여자를 만났어, 알지, 인터넷 토론 그룹 같은 거? 조언이 필요해. Claudia라는 여자야...
# 음, 상대와의 관계에 따라 달라. 이제 Claudia, 네 여자친구 말인데...
# 'Ich freu me senselen...?'
# 알았어...
# 많은 사람들이 탄산음료를 많이 마셔서 살이 쪄. 탄산음료는 가끔 즐기는 정도여야 해. 거기엔 영양가가 전혀 없거든. 만약 체중을 줄이고 싶지만 탄산음료를 끊지 못하겠다면...
# 아닙니다, 죄송하지만, 주차장 북쪽 끝에서 앉으시면 무료 무선 인터넷 연결 가능해요. 옆 호텔에서 신호가 오거든요...
# 호텔들이 이렇게 하면 참 짜증 나죠. 여러 호텔에서 다 체크해봤는데 말이죠...
# (웃으며) 아, 그러게요... 이제 너무 혼란스러워서요. 다른 호텔들은 이런 편의시설 무료로 제공하거든요.
# 오, 저는 되는데요. 제 전화는 꽤 잘 터져요. 어디 보자... 비가 한 시간 더 온다고 하네요. 택시를 잡아야겠어요.
# 아, 맞아. 기차라면 늦지 말아야지. 그럼 결론은... Bill은 아마도 늦잠 잤을 거야.
# 꽤 좋아. 저기... University Avenue에 새로 생긴 타이 레스토랑 알아?
# 알겠어, 나 간다... 근데, 너 왜 아직 있어?
# 뭐? 글쎄, 나는 그냥... 그냥 가볍게 피우는 거고, 언제든 끊을 수 있어.
# 응, 근데 처음이야... 요새 스트레스 많이 받나 봐.
# 뭐, 너도 알다시피, 난 고기를 많이 먹지 않아서...
# 아, 여기 있네. Patulin이라... 아이고!
# 알았어요. 침대로 돌아갈게요...
# 항로가 깨끗해 보입니다, 캡틴...
# 사령관? 컴퓨터... 사령관 크르도비를 찾아줘.
# 컴퓨터...(BEEP BEEP). 배에서 떠나기 전후 1분 동안 이 배의 상태는 어땠어?
# 다리에서 수송실로... 중위, 응답해 주세요. 보안팀은 즉시 수송실로 보고하고 조사하세요.
# 이제 다시 다리로 돌아가서...
# 캡틴? 컴퓨터...(BEEP BEEP). 멜로니 두로셋 캡틴을 찾아줘.
# 갑자기 다섯 대의 외계인 함선이 장거리 스캐너에 나타나 그들을 향해 직진합니다. 다리의 그린필드 씨가 모티아 사령관에게 보고합니다...
# 네, 알겠습니다. 제가 이번 주말에 시간이 좀 되는데...
# 물론이지, 어디 보자... 개인 정보, 학력, 경력, 교육... 내가 보기엔 언어 능력을 추가하는 게 좋을 것 같아. 너 세 개 국어 하잖아. 그걸 이력서에 쓰는 게 좋을 것 같아.
# 물론이지, 어디 보자... 개인 정보, 학력, 경력, 교육... 내가 보기엔 언어 능력을 추가하는 게 좋을 것 같아. 너 세 개 국어 하잖아. 그걸 이력서에 쓰는 게 좋을 것 같아.
# 잘 모르겠어. 좀 이상한 상황이야. Brandon이 이 여자랑 사귀었는데... 알잖아, Alex? 걔랑 사귀다가, 결국 헤어졌어. 그 애가 약을 하길래...
# 잘 모르겠어. 좀 이상한 상황이야. Brandon이 이 여자랑 사귀었는데... 알잖아, Alex? 걔랑 사귀다가, 결국 헤어졌어. 그 애가 약을 하길래...
# 그래, 그렇긴 한데 지금은 그녀가 Brandon에게 엄청 화가 나서 여러모로 문제가 많아. 지난주에 학교에서 그녀가 Brandon 얼굴이랑... 아랫배를 쳤어. 다들 보는 앞에서.
# Brandon은 처음에는 그냥 넘어가려고 했는데, 괜히 더 문제를 만들고 싶지 않다고 했거든...
# 거기가 좀 멀긴 한데... 어쩔 수 없겠네.
# 음, 내가 시계를...
# 65달러? 이게 무슨 소리야...?
# 많은 스타들이 나와, Andy, Justin, Mendy 같은 사람들...
# 잠깐만, 저거...? 도넛? 그거 유기농 도넛이야, Kelly?
# 그러면... 따로 스위치는 켤 필요 없어.
# 여기 있네요... 그리고 여기 스포츠 셔츠가 있어요.
# 좋습니다. 사인만 해주시면 됩니다...
# 매일 밤 일요일을 제외하고 열려요. 잠시만요... 네, 공연은 7월 초까지 진행될 예정이에요. 저녁 8시에 시작해서 2시간 반 정도 지속되어 10시 45분에 끝나요. 여기 전단지를 가져가세요. 더 많은 정보를 보실 수 있어요.
# 정말? 왜 그렇게 극단적인 방법인 파업까지 가야 해? 너희 회사가 꽤 좋은 이미지인 걸로 알고 있었는데. 본사 사람들이 머리 아플 것 같은데, 파업 같은 심각한 일이 일어나니까...
# 실제로 꽤 자주 일어나는 일이야. 노동조합이랑 경영진 사이에 분쟁이 생기면 첫 번째로 하는 게 파업이거든. 보통 하루 이틀 안에 양측이 합의하고 우리는 다시 일하기 시작해. 어쨌든 이번에는 예기치 않은 휴일이긴 하네...
# 더블룸을 원하시는군요? 잠시만요... 1405호로 안내해 드릴 수 있습니다. 강이 보이고 전망이 아주 좋습니다.
# 첫 번째 단계는 미국 비자 자격 여부를 결정하는 것입니다. 보자... 특별 사업 비자를 신청하셨네요. 왜 그런가요?
# 알겠습니다. 모터부터 한번 점검해볼게요. 플러그를 뽑고 기계 내부를 확인하겠습니다... 아, 네. 문제점이 보이네요. 꽤 간단해요. 몇 분 안에 해결하겠습니다.
# 아, 저기... 죄송한데, 청소할 시간이 없어서 그래요.
# 파일이 너무 큰 것 같아요. 메모리를 늘려야 할 거예요. 일단, 열려 있는 모든 파일을 닫고, 그다음에...
# 우리 새 클럽 가는 거잖아. 진짜 빨리 무대에 나가고 싶어...
# 아이고... 그래도 안 갈래. 요즘 몸도 별로 안 좋아.
# (나중에...) 다 먹음직스러워 보여. 뭐 먹고 싶어?
# 언젠가 이렇게 될 줄 알았어...
# 음, 이건 전부 내 잘못은 아니야, 안나...
# 아니야, 사실 월요일이랑 수요일에는...
# 아, 또 아닌 걸 말하네...
# 하지만... 그리고 일요일에는 운동은 안 하는데, 보통 개와 산책하러 가.
# 맞아, 절대 늦지 않지. 그런데...
# 아니요, 다른 거요... 네, 그거요.
# 어디 보자... 한 800달러 정도 나올 것 같습니다.
# 겁쟁이! 그러면... 좋아. 월요일에 호수에 가자. 화요일에는 산악 자전거 타러 가는 거야. 음, 그날은 흐리다더라, 네 피부는 괜찮을 거야.
# 아, 그거 좋다... 근데 저번처럼 또 넘어져서 팔이라도 부러질 것 같아.
# 저번에도 팔 안 부러졌잖아. 이번에도 안 부러질 거야. 자, 월요일에는 호수에 가고, 화요일에는 산악 자전거를 탈 거야. 음, 수요일에는 낚시하러 가자고 생각했어. 저번에 갔을 때 기억나? 나 엄청 큰 물고기 10마리나 잡았었잖아...
# 알다시피, 보드게임 좋아하는데 그건 언제든 할 수 있잖아. 그러니까... 금요일이나 토요일에 다 이야기한 것들 하고 나서, 금요일이나 토요일에 산으로 소풍 가는 거 어때? 네 팔도 안 부러지고, 햇볕에도 안 탈 거야. 정말 괜찮을 거야. 그렇게 하자, 응?
# 잠시만요... 죄송하지만, 원하는 테이블은 예약이 꽉 찼습니다.
# 너 좀 과민반응하는 거 아니야? 별명으로 부르는 게 그렇게 나쁘진 않잖아...
# 🧾 dev_cleaned2.csv 결과:
#  - 앞 글자 수 2개 이상 ('안녕...'): 60개
#
# 파일: test_cleaned2.csv
#
# 네, 말씀하세요...
# 모든 직원에게 알립니다... 즉시 발효되어 모든 사내 통신은 이메일과 공식 메모로만 제한됩니다. 근무 시간 동안 즉시 메시지 프로그램 사용은 금지됩니다.
# 감사합니다. 잠깐만요... 이건 뭔가요? 30달러는 어디서 나온 건가요?
# 알아... 알아... 전부 내 잘못이야. 공부 안 한 것도, 부정행위 한 것도 들킨 것도 다 너무 후회돼.
# 알아... 알아... 전부 내 잘못이야. 공부 안 한 것도, 부정행위 한 것도 들킨 것도 다 너무 후회돼.
# 빨리! 사진 찍어! ... 넘겨줘!
# 네가 이렇게 나올 줄 알았어...
# 바보 같은 여자애 때문에 돈이 이렇게 많이 필요할 줄이야. 이제 ATM에서 돈을 찾아야겠네...
# 카드 넣는 것 정도는 알아, 이 멍청한 기계가 나를 바보로 만드네...
# 3학년인데 그 수업에 등록할 수 있을지 궁금해서요. 대학원 과목인 건 알지만...
# 잠시만요... 수요일 오전이죠. 네, 오전 내내 꽉 차 있어요. 무슨 일이세요?
# 어떻게 하지? 오늘 오후까지 이 보고서를 끝내야 하는데...
# 아니요. 하지만 대략적인 추정치를 드릴 수 있을 거고, 그 숫자를 기준으로 예산을 짤게요. 초대장은 100장을 보냈어요...
# 네, 하지만 방이...
# 물론, 하하... 30명 정도밖에 오지 않을 것 같아요.
# 그럼 만약 많은 사람이 오면요? 그날은 이 방밖에 없어요. 연회장에는 결혼 피로연이 있어서...
# 그렇다면, 저는...
# 맞아요. 여기 정부는 문제를 해결하고 새로운 기술을 활용해 비즈니스를 더 잘 운영할 수 있게 해줍니다. 하지만 저는 캐나다 사람들이 일반적으로 러시아 사람들보다 더 차분하다고 생각해요... 그리고 미국 사람들보다도 분명히 더 여유롭죠!
# 아니요, 그것도 제가 아니에요. 죄송합니다, 손님. 아마 제가 익숙하게 느껴지시는 걸 수도 있는데...
# 아, 아니요, 그냥 ...
# 알겠어요...
# 음, 사실은 ... 네. 저기... 과학박물관에 가고 싶은데 몇 시간째 길을 잃어버렸어요. 이 티켓 기계도 어떻게 해야 할지 모르겠고요.
# 음, 사실은 ... 네. 저기... 과학박물관에 가고 싶은데 몇 시간째 길을 잃어버렸어요. 이 티켓 기계도 어떻게 해야 할지 모르겠고요.
# 음, 난 외향적이고 다정하고 사람 차별하지 않는 여자가 좋아. 그리고 자기중심적인 사람은 싫어... 아는 누구처럼.
# 잠깐만 보자... 다다음 주말이 괜찮아 보이네. 그 외엔 다 예약이 꽉 찼어.
# 오, 자기야, 무사하다니 다행이야! 근데 나한테 좋은 소식 있어... 나 임신한 것 같아!
# Jess요? 음, 그녀는 정말 똑똑하고 유머감각이 뛰어나요. 그리고 아주 여성스러워요...
# 사실은... Jess에게 프로포즈도 생각하고 있었어요... 그냥 너무 긴장돼서요.
# 사실은... Jess에게 프로포즈도 생각하고 있었어요... 그냥 너무 긴장돼서요.
# 안녕, Andrew! 안녕 ...? Andrew.
# 난 누나잖아. 내가 ... 뭐야? 너보다 세 살 많으니까 말하고 싶으면 솔직할 수 있어. 게다가, 너 항상 나한테 그런 말 하곤 했잖아. 나 어릴 때 너 나한테 뚱뚱하다고 그랬잖아.
# 아, 설명하기 너무 복잡해. 며칠 전에 스팸메일에서 정보 찾았거든 ...
# 아, 그건 확인 안 해봤는데 ... 하지만, 하지만, 하지만 ... 그런 것 같아.
# 아, 그건 확인 안 해봤는데 ... 하지만, 하지만, 하지만 ... 그런 것 같아.
# 잘 들어, 너 사기당하는 것 같아, 그거 진짜로 이상해. 나 뚱뚱하지 않으니까 믿어. ... 체중 감량하고 싶으면 제대로 해야 돼.
# 그게 ...
# 저칼 ... 아니야, 저칼로리가 아냐. 여기 봐봐. Andrew! 너 먹는 게 아이스크림밖에 없네.
# 글쎄 ...
# 그게 ...
# 아, 이거군요... 여기 있습니다.
# 퀸즈 로드를 따라...
# 친절하시네요. 감사합니다. 저기... 연필 있으세요?
# 아냐, 괜찮아. 로마에 가면 로마법을 따르라고 하잖아...
# 잠시만요... 여기에는 손님 표에 대한 정보가 없는 것 같아요.
# 네, 하지만...
# 🧾 test_cleaned2.csv 결과:
#  - 앞 글자 수 2개 이상 ('안녕...'): 80개

# %%
# CSV 파일 불러오기
df = pd.read_csv("data/train.csv")

def preprocess_dialogue(text):
    # fix1
    # \n이 잘못 표시된 경우를 옳게 변경
    # 1. 정규표현식으로 대사 추출
    pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
    raw_dialogues = re.findall(pattern, text, flags=re.DOTALL)

    # fix1
    # 2. 각 문장에서 맨 마지막 문장부호까지 포함한 문장만 남기기
    cleaned_dialogues = []
    for d in raw_dialogues:
        d = d.strip()
        match = re.search(r'^(#Person\d#:.+[.!?])', d, flags=re.DOTALL)
        if match:
            cleaned_dialogues.append(match.group(1).strip())
        else:
            cleaned_dialogues.append(d) # 예외 처리: 문장부호 없을 경우 전체 사용

    # fix1
    # 문장 사이에 \n 삽입
    answer = '\n'.join(cleaned_dialogues)
    
    return answer

# .이 4개 이상인 경우, ...으로 대체 (.이 4개, 5개 있는 경우가 있음)
for v in ['.....', '....']:
    df['dialogue'] = df['dialogue'].apply(lambda x:x.replace(v, '...'))

# \n이나 \<br> 표현 옳게 수정
df['dialogue'] = df['dialogue'].apply(preprocess_dialogue)

# ㅎㅎ를 문맥에 맞게 수정
df['dialogue'] = df['dialogue'].apply(lambda x:x.replace('ㅎㅎ', '나도 기쁘다.'))

# 새로운 CSV 파일로 저장 (index 없이)
df.to_csv("data/filtered_dialogues.csv", index=False)

# %% [markdown]
# # '[', ']'가 포함된 문장

# %% [markdown]
# ### '['로 시작하고 ']'로 안 끝나는 부분 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    count = 0

    # 2. [로 시작하고 ]로 안 끝나는 부분
    print(f"{file_name} '['로 시작하고 ']'로 안 끝나는 부분:")

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            for match in re.finditer(r'\[([^\]]*?)(?=\[|$)', d):
                count += 1
                print(f" - {d}")

    print(f"🧾 {file_name} 결과:")
    print(f" - '['로 시작하고 ']'로 안 끝나는 부분 : {count}개")
# Out:
# 파일: train_cleaned.csv
#
# train_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
#  - #Person1#: 저기, 방금 그 소리는 뭐죠? [아아!
#
#  - #Person1#: 진정하세요. [가장 좋아하는 단어군요...
#
#  - #Person2#: 알겠어요. 헉? [보안 경보가 울림...
#
# 🧾 train_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 3개
#
# 파일: dev_cleaned.csv
#
# dev_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
# 🧾 dev_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 0개
#
# 파일: test_cleaned.csv
#
# test_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
# 🧾 test_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 0개

# %% [markdown]
# ### 수정

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    modified_dialogues = []

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        new_blocks = []

        for d in raw_dialogues:
            # 복사본 유지
            modified_text = d
            for match in re.finditer(r'\[([^\]]*?)(?=\[|$)', d):
                inner = match.group(1)
                if inner.strip() == "보안 경보가 울림...":
                    modified_text = modified_text.replace(match.group(), f"({inner.strip()})")
                else:
                    modified_text = modified_text.replace(match.group(), "")
            new_blocks.append(modified_text.strip())

        modified_dialogue = '\n'.join(new_blocks)
        modified_dialogues.append(modified_dialogue)

    df['dialogue'] = modified_dialogues

    # 저장
    output_path = os.path.join('data', file_name)
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    count = 0

    # 2. [로 시작하고 ]로 안 끝나는 부분
    print(f"{file_name} '['로 시작하고 ']'로 안 끝나는 부분:")

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            for match in re.finditer(r'\[([^\]]*?)(?=\[|$)', d):
                count += 1
                print(f" - {d}")

    print(f"🧾 {file_name} 결과:")
    print(f" - '['로 시작하고 ']'로 안 끝나는 부분 : {count}개")
# Out:
# 파일: train_cleaned.csv
#
# train_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
# 🧾 train_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 0개
#
# 파일: dev_cleaned.csv
#
# dev_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
# 🧾 dev_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 0개
#
# 파일: test_cleaned.csv
#
# test_cleaned.csv '['로 시작하고 ']'로 안 끝나는 부분:
# 🧾 test_cleaned.csv 결과:
#  - '['로 시작하고 ']'로 안 끝나는 부분 : 0개

# %% [markdown]
# ### '['로 시작하지 않고 ']'로 끝나는 부분 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    count = 0

    # 3. [로 시작하지 않고 ]로 끝나는 부분
    print(f"{file_name} '['로 시작하지 않고 ']'로 끝나는 부분:")

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            temp = re.sub(r'\[[^\[\]]*?\]', '', d)
            # 그 뒤에 ]만 남아있는 경우 찾기
            for match in re.finditer(r'[^\[\]\n]+?\]', temp):
                count += 1
                print(f" - {d}")

    print(f"🧾 {file_name} 결과:")
    print(f" - '['로 시작하지 않고 ']'로 끝나는 부분 : {count}개")
# Out:
# 파일: train_cleaned.csv
#
# train_cleaned.csv '['로 시작하지 않고 ']'로 끝나는 부분:
# 🧾 train_cleaned.csv 결과:
#  - '['로 시작하지 않고 ']'로 끝나는 부분 : 0개
#
# 파일: dev_cleaned.csv
#
# dev_cleaned.csv '['로 시작하지 않고 ']'로 끝나는 부분:
# 🧾 dev_cleaned.csv 결과:
#  - '['로 시작하지 않고 ']'로 끝나는 부분 : 0개
#
# 파일: test_cleaned.csv
#
# test_cleaned.csv '['로 시작하지 않고 ']'로 끝나는 부분:
# 🧾 test_cleaned.csv 결과:
#  - '['로 시작하지 않고 ']'로 끝나는 부분 : 0개

# %% [markdown]
# ### '['와 ']'로 감싸진 부분 출력

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    count = 0

    # 1. [와 ]로 감싸진 부분 (올바르게 닫힌 괄호)
    print(f"{file_name} '['와 ']'로 감싸진 부분:")

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            for match in re.finditer(r'\[([^\[\]]*?)\]', d):
                person_tags = re.findall(r'#Person(\d+)#', dialogue)
                if person_tags:
                    max_person_id = max(map(int, person_tags))
                    print(f"👥 max #PersonN# in this dialogue: {max_person_id}")
                count += 1
                print(f" - {d}")

    print(f"🧾 {file_name} 결과:")
    print(f" - '['와 ']'로 감싸진 부분 : {count}개")
# Out:
# 파일: train_cleaned.csv
#
# train_cleaned.csv '['와 ']'로 감싸진 부분:
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 그 친구 좀 보게 해 줘. [아빠가 거실 창밖을 봄] ... 저 사람 콧수염 있었네!
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 알아, 알아, 근데 모르겠어. 나는 지금 맥도날드에서 일하고 있는 걸 출세의 한 단계로 보고 있어. [맥도날드!]. 근데, 학교에 다시 갈 자원이 없어서 하지만, 내가 알아본 직장은 6개월 후에 일부 수업비를 지원해줄 거래.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 보세요, Mr. Adams. 제 금융 상담가와 상의했어요 [뭐?], 아, 제 엄마요. 엄마가 말씀하시길, 제가 요리도 하고 당신 집도 청소해드리니 아이 한 명당 더 많은 요금을 받아야 한다고 하세요.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: [웃음] 여기저기 조금 있어요. 들어보세요. 이 열 장의 음반을 오십 달러에 드릴게요. 정말 싼 거예요!
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 어디? 보여 줘 봐. [봐봐!] 흠집 안 보이는데.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 여기, 여기! [저거?] [보]이니?
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 여기, 여기! [저거?] [보]이니?
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 별로 좋은 이유도 아니야. 자립심을 길러야 한다거나, 권리만 주장하지 말라거나 그런 거야. 이웃 농장에서 일해서 돈 벌라는 말씀도 하셨어. [좋은 생각이네!] 불공평해.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 있잖아, 문제를 알 것 같아. [뭐?] 거울 한번 봐봐. 거기서 문제도 해결책도 찾을 수 있을 거야.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 

#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 정말로? 그럼 이 담배들은 뭐야? [뭐라고?] 여기에! [아! ] 걔가 어젯밤에 우리 집에 있을 때 옷에서 발견했어. 들어 봐.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person1#: 정말로? 그럼 이 담배들은 뭐야? [뭐라고?] 여기에! [아! ] 걔가 어젯밤에 우리 집에 있을 때 옷에서 발견했어. 들어 봐.
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 갈게요. 아, 배고파 죽겠어요. [좋아, 좋아.] 으악! 이게 뭐야?
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 나한테 보여줘 봐... 아, 아빠. [뭐?] 레시피 한 페이지를 빠뜨리셨나 봐요!
#
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 나도 먹어볼래요 아빠. 빨리 주세요. 아빠, 소금을 많이 넣으셨고, 더군다나 탔잖아요. [음...] 저건 또 뭐야?
#
# 🧾 train_cleaned.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 59개
#
# 파일: dev_cleaned.csv
#
# dev_cleaned.csv '['와 ']'로 감싸진 부분:
# 👥 max #PersonN# in this dialogue: 2
#  - #Person2#: 참 어이가 없네. 내가 뭘 듣고 있는지도 모르겠어. 어, 어디 보자? 달걀 하나, 우유 한 갤런에 2.50달러, 참치캔 세 개. 좋아. [응.] 마지막으로 8.14달러짜리 스테이크 두 개. 이제야 제대로 된 게 있네. 내가 그릴에 불 붙일게.
#
# 🧾 dev_cleaned.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 1개
#
# 파일: test_cleaned.csv
#
# test_cleaned.csv '['와 ']'로 감싸진 부분:
# 🧾 test_cleaned.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 0개

# %% [markdown]
# ### 수정

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned.csv', 'dev_cleaned.csv', 'test_cleaned.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    modified_dialogues = []

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        new_blocks = []

        for d in raw_dialogues:
            if "[보]이니" in d:
                d = d.replace("[보]이니", "보이니")
            elif "[이 문제는]" in d:
                d = d.replace("[이 문제는]", "이 문제는")
            modified_text = d

            # 처리 완료된 부분을 저장할 리스트
            processed_blocks = []
            # 임시 저장 변수(수정 진행용)
            temp_text = modified_text
            # 현재 발화자 추출 (#Person1# or #Person2#)
            speaker_match = re.match(r'(#Person\d#:)', d)
            speaker = speaker_match.group(1) if speaker_match else "#Person1#:"
            other_speaker = "#Person2#:" if speaker == "#Person1#:" else "#Person1#:"

            # [] 괄호 안 특정 텍스트는 ()로 대체(원래 코드)
            for match in re.finditer(r'\[([^\[\]]*?)\]', d):
                inner = match.group(1).strip()
                if inner in ['엔진 시작...', '문 두드리는 소리.', '웃으며', '초인종 소리', '웃음', '펀치와 발차기, 비명 소리...', '여자가 차 시동을 걸어보는데...', '아빠가 거실 창밖을 봄']:
                    modified_text = modified_text.replace(match.group(), f"({inner})")

            # else: -- 여기서 [] 괄호 안 텍스트는 상대방 발화로 분리
            # 괄호 안 텍스트가 특수 사운드가 아니면 분리 작업
            # -> 괄호 안 텍스트 추출하여, 괄호 제거하고 새 줄로 추가

            # 먼저 수정된 텍스트를 기반으로 다시 처리 (괄호를 대화 분리용으로)
            temp_text = modified_text
            output_blocks = []

            while True:
                m = re.search(r'\[([^\[\]]+?)\]', temp_text)
                if not m:
                    remainder = temp_text.strip()
                    if remainder:
                        # 발화자 태그 제거 후 내용만 남김
                        remainder_clean = re.sub(r'^#Person\d#:\s*', '', remainder)
                        output_blocks.append(f"{speaker} {remainder_clean}")
                    break

                start, end = m.span()
                before = temp_text[:start].strip()
                inside = m.group(1).strip()
                after = temp_text[end:].strip()

                inside_words = inside.split()
                last_word = inside_words[-1] if inside_words else ''

                # after의 첫 글자가 문장부호인지 확인
                if last_word and last_word[-1] in ['.', ',', '!', '?']:
                    if after and after[0] in ['.', ',', '!', '?']:
                        # 중복된 문장부호 제거 위해 after에서 첫 글자 제거
                        after = after[1:].lstrip()

                # before 발화자 태그 제거
                before_clean = re.sub(r'^#Person\d#:\s*', '', before)

                if before_clean:
                    output_blocks.append(f"{speaker} {before_clean}")

                if not inside.endswith(('.', ',', '!', '?', ']')):
                        inside += '.'
                output_blocks.append(f"{other_speaker} {inside}")

                temp_text = after

            new_blocks.extend(output_blocks)

        modified_dialogue = '\n'.join(new_blocks)
        modified_dialogues.append(modified_dialogue)

    df['dialogue'] = modified_dialogues

    # 저장
    output_path = os.path.join('data', file_name.replace('_cleaned', '_cleaned2'))
    df.to_csv(output_path, index=False)
    print(f'✅ 저장 완료: {output_path}')
# Out:
# 파일: train_cleaned.csv
#
# ✅ 저장 완료: data/train_cleaned2.csv
#
# 파일: dev_cleaned.csv
#
# ✅ 저장 완료: data/dev_cleaned2.csv
#
# 파일: test_cleaned.csv
#
# ✅ 저장 완료: data/test_cleaned2.csv

# %% [markdown]
# ### 수정 완료 확인

# %%
# 체크할 파일 리스트
file_list = ['train_cleaned2.csv', 'dev_cleaned2.csv', 'test_cleaned2.csv']

for file_name in file_list:
    print(f'\n파일: {file_name}\n')

    try:
        df = pd.read_csv(os.path.join('data', file_name))
    except Exception as e:
        print(f'{file_name} 로딩 실패: {e}')
        continue

    count = 0

    # 1. [와 ]로 감싸진 부분 (올바르게 닫힌 괄호)
    print(f"{file_name} '['와 ']'로 감싸진 부분:")

    for dialogue in df['dialogue']:
        # 대사 블록 단위로 분리
        pattern = r'#Person\d#:.+?(?=(?:#Person\d#:|$))'
        raw_dialogues = re.findall(pattern, dialogue, flags=re.DOTALL)

        for d in raw_dialogues:
            for match in re.finditer(r'\[([^\[\]]*?)\]', d):
                count += 1
                print(f" - {d}")

    print(f"🧾 {file_name} 결과:")
    print(f" - '['와 ']'로 감싸진 부분 : {count}개")
# Out:
# 파일: train_cleaned2.csv
#
# train_cleaned2.csv '['와 ']'로 감싸진 부분:
# 🧾 train_cleaned2.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 0개
#
# 파일: dev_cleaned2.csv
#
# dev_cleaned2.csv '['와 ']'로 감싸진 부분:
# 🧾 dev_cleaned2.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 0개
#
# 파일: test_cleaned2.csv
#
# test_cleaned2.csv '['와 ']'로 감싸진 부분:
# 🧾 test_cleaned2.csv 결과:
#  - '['와 ']'로 감싸진 부분 : 0개
